# %% [markdown]
# # 06b. Timebanks: Modeling Results (1/24/19 - 3/3/19)
# > Author: [Dawn Graham](https://dawngraham.github.io/)
#
# Models created with: `combined_2019-01-24_2019-03-03.csv`
#
# Summaries of models included below:
# - Best model for ALL timebanks
# - Best model for ACTIVE timebanks
# - Decision tree for ALL timebanks
# - Lasso for ALL timebanks
# - Linear regression models for ACTIVE timebanks
# - Linear regression models for ALL timebanks
#
# For linear regression models, I used backward feature selection. I started with all features and removed one at a time, using RMSE as metric to judge if the model improved with removal. The models are ordered with the most recent closer to the top of the notebook.
#
# ---

# %% [markdown]
# ## Best model for ALL timebanks

# %% [markdown]
# ### Model ID: 190303_190928 - ALL timebanks
#
# This is the decision tree that performed best previously in notebook 06a.
#
# #### Selected model
# DecisionTreeRegressor(criterion='mse', max_depth=4, max_features='auto',
#            max_leaf_nodes=15, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            presort=False, random_state=42, splitter='random')
#
# #### Features
# ['const', 'phone', 'facebook', 'mission_sentiment', 'notes_word_count', 'hours_per_exchange', 'avg_offers', 'avg_requests', 'offer_request_ratio', 'categories_with_requests']
#
# |Metric|Value|
# |-----|-----|
# |**Training R2**|0.76454|
# |**Testing R2**|0.60166|
# |**Explained variance**|0.60212|
# |**Mean absolute error (MAE)**|0.40277|
# |**Mean squared error (MSE)**|0.62021|
# |**Root mean squared error (RMSE)**|0.78754|
# |**Median absolute error (MedAE)**|0.14380|
# |**Mean distribution of residuals**|-0.02688|
#
#
# <table><tr><td><img src="../images/dist_190303_190928.png"></td><td><img src="../images/prob_190303_190928.png"></td></tr></table>
# <img src="../images/tree_190303_190928.png">
#
#
# ---

# %% [markdown]
# ## Best model for ACTIVE timebanks

# %% [markdown]
# ### Model ID: 190303_192915 - ACTIVE timebanks
#
# This uses features selected by doing backward selection for the linear regression model (Model ID: 190303_174431 - ACTIVE timebanks) and hyperparameters determined by gridsearch.
#
# #### Selected model
# DecisionTreeRegressor(criterion='mse', max_depth=1, max_features='sqrt',
#            max_leaf_nodes=2, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=1.0, min_weight_fraction_leaf=0.0,
#            presort=False, random_state=42, splitter='random')
#
# #### Features
# ['const', 'phone', 'mission_word_count', 'avg_offers', 'avg_requests', 'offer_request_ratio', 'members_starting', 'members_daily_new', 'facebook_likes', 'facebook_followers', 'twitter_tweets', 'categories_total', 'categories_with_requests']
#
# |Metric|Value|
# |-----|-----|
# |**Training R2**|0.20219|
# |**Testing R2**|0.14266|
# |**Explained variance**|0.14296|
# |**Mean absolute error (MAE)**|0.67994|
# |**Mean squared error (MSE)**|0.84308|
# |**Root mean squared error (RMSE)**|0.91819|
# |**Median absolute error (MedAE)**|0.51206|
# |**Mean distribution of residuals**|0.01710|
#
#
# <table><tr><td><img src="../images/dist_190303_192915.png"></td><td><img src="../images/prob_190303_192915.png"></td></tr></table>
# <img src="../images/tree_190303_192915.png">
#
# ---

# %% [markdown]
# ---
#
# ## Decision Trees

# %% [markdown]
# ### Model ID: 190303_192915 - ACTIVE timebanks
#
# This uses features selected by doing backward selection for the linear regression model (Model ID: 190303_174431 - ACTIVE timebanks) and hyperparameters determined by gridsearch.
#
# #### Selected model
# DecisionTreeRegressor(criterion='mse', max_depth=1, max_features='sqrt',
#            max_leaf_nodes=2, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=1.0, min_weight_fraction_leaf=0.0,
#            presort=False, random_state=42, splitter='random')
#
# #### Features
# ['const', 'phone', 'mission_word_count', 'avg_offers', 'avg_requests', 'offer_request_ratio', 'members_starting', 'members_daily_new', 'facebook_likes', 'facebook_followers', 'twitter_tweets', 'categories_total', 'categories_with_requests']
#
# |Metric|Value|
# |-----|-----|
# |**Training R2**|0.20219|
# |**Testing R2**|0.14266|
# |**Explained variance**|0.14296|
# |**Mean absolute error (MAE)**|0.67994|
# |**Mean squared error (MSE)**|0.84308|
# |**Root mean squared error (RMSE)**|0.91819|
# |**Median absolute error (MedAE)**|0.51206|
# |**Mean distribution of residuals**|0.01710|
#
#
# <table><tr><td><img src="../images/dist_190303_192915.png"></td><td><img src="../images/prob_190303_192915.png"></td></tr></table>
# <img src="../images/tree_190303_192915.png">
#
# ---

# %% [markdown]
# ### Model ID: 190303_190928 - ALL timebanks
#
# This is the decision tree that performed best previously in notebook 06a.
#
# #### Selected model
# DecisionTreeRegressor(criterion='mse', max_depth=4, max_features='auto',
#            max_leaf_nodes=15, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            presort=False, random_state=42, splitter='random')
#
# #### Features
# ['const', 'phone', 'facebook', 'mission_sentiment', 'notes_word_count', 'hours_per_exchange', 'avg_offers', 'avg_requests', 'offer_request_ratio', 'categories_with_requests']
#
# |Metric|Value|
# |-----|-----|
# |**Training R2**|0.76454|
# |**Testing R2**|0.60166|
# |**Explained variance**|0.60212|
# |**Mean absolute error (MAE)**|0.40277|
# |**Mean squared error (MSE)**|0.62021|
# |**Root mean squared error (RMSE)**|0.78754|
# |**Median absolute error (MedAE)**|0.14380|
# |**Mean distribution of residuals**|-0.02688|
#
#
# <table><tr><td><img src="../images/dist_190303_190928.png"></td><td><img src="../images/prob_190303_190928.png"></td></tr></table>
# <img src="../images/tree_190303_190928.png">
#
#
# ---

# %% [markdown]
# ### Model ID: 190303_171509 - ALL timebanks
#
# This uses features selected by doing backward selection for the linear regression model (Model ID: 190303_164804 - ALL timebanks) and hyperparameters determined by gridsearch.
#
# #### Selected model
# DecisionTreeRegressor(criterion='mse', max_depth=3, max_features='sqrt',
#            max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=3, min_weight_fraction_leaf=0.0,
#            presort=False, random_state=42, splitter='best')
#
# #### Features
# ['const', 'sponsor', 'phone', 'url_2', 'mission_word_count', 'mission_sentiment', 'notes_sentiment', 'members_starting', 'members_daily_new', 'facebook_likes', 'facebook_followers', 'twitter_tweets', 'twitter_following', 'twitter_followers', 'categories_total', 'categories_parent', 'categories_with_requests', 'talent_per_cat_per_member']
#
# |Metric|Value|
# |-----|-----|
# |**Training R2**|0.77477|
# |**Testing R2**|0.54111|
# |**Explained variance**|0.58752|
# |**Mean absolute error (MAE)**|0.42830|
# |**Mean squared error (MSE)**|0.71448|
# |**Root mean squared error (RMSE)**|0.84527|
# |**Median absolute error (MedAE)**|0.03195|
# |**Mean distribution of residuals**|0.26882|
#
#
# <table><tr><td><img src="../images/dist_190303_171509.png"></td><td><img src="../images/prob_190303_171509.png"></td></tr></table>
#
# <img src="../images/tree_190303_171509.png">
#
# ---

# %% [markdown]
# ---
#
# ## Linear Regression for ACTIVE Timebanks

# %% [markdown]
# ### Model ID: 190303_174613 - ACTIVE timebanks
# #### Selected model
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)
#
# #### Features
# ['const', 'phone', 'mission_word_count', 'avg_offers', 'avg_requests', 'offer_request_ratio', 'members_daily_new', 'facebook_likes', 'facebook_followers', 'twitter_tweets', 'categories_total', 'categories_with_requests']
#
# |Metric|Value|
# |-----|-----|
# |**Training R2**|0.48387|
# |**Testing R2**|-8.95556|
# |**Explained variance**|-7.34724|
# |**Mean absolute error (MAE)**|2.30414|
# |**Mean squared error (MSE)**|9.78997|
# |**Root mean squared error (RMSE)**|3.12889|
# |**Median absolute error (MedAE)**|1.59994|
# |**Mean distribution of residuals**|1.25760|
#
#
# <table><tr><td><img src="../images/dist_190303_174613.png"></td><td><img src="../images/prob_190303_174613.png"></td></tr></table>
#
#
# ---

# %% [markdown]
# ### Model ID: 190303_174530 - ACTIVE timebanks
# #### Selected model
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)
#
# #### Features
# ['const', 'phone', 'mission_word_count', 'avg_offers', 'avg_requests', 'offer_request_ratio', 'members_starting', 'members_daily_new', 'facebook_likes', 'facebook_followers', 'twitter_tweets', 'categories_total']
#
# |Metric|Value|
# |-----|-----|
# |**Training R2**|0.52449|
# |**Testing R2**|-6.62789|
# |**Explained variance**|-5.12177|
# |**Mean absolute error (MAE)**|1.99567|
# |**Mean squared error (MSE)**|7.50102|
# |**Root mean squared error (RMSE)**|2.73880|
# |**Median absolute error (MedAE)**|1.18634|
# |**Mean distribution of residuals**|1.21699|
#
#
# <table><tr><td><img src="../images/dist_190303_174530.png"></td><td><img src="../images/prob_190303_174530.png"></td></tr></table>
#
#
# ---

# %% [markdown]
# ### Model ID: 190303_174431 - ACTIVE timebanks
# #### Selected model
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)
#
# #### Features
# ['const', 'phone', 'mission_word_count', 'avg_offers', 'avg_requests', 'offer_request_ratio', 'members_starting', 'members_daily_new', 'facebook_likes', 'facebook_followers', 'twitter_tweets', 'categories_total', 'categories_with_requests']
#
# |Metric|Value|
# |-----|-----|
# |**Training R2**|0.61015|
# |**Testing R2**|-1.48992|
# |**Explained variance**|-1.21143|
# |**Mean absolute error (MAE)**|1.32144|
# |**Mean squared error (MSE)**|2.44851|
# |**Root mean squared error (RMSE)**|1.56477|
# |**Median absolute error (MedAE)**|1.45372|
# |**Mean distribution of residuals**|0.52332|
#
# |Feature	|Coef|
# |-----|-----|
# |avg_requests	|85.055094|
# |facebook_followers	|15.119735|
# |phone	|2.052697|
# |members_starting	|0.890247|
# |categories_with_requests	|0.871565|
# |offer_request_ratio	|0.308144|
# |members_daily_new	|0.033637|
# |categories_total	|0.018553|
# |const	|0.000000|
# |mission_word_count	|-0.032245|
# |twitter_tweets	|-0.617539|
# |facebook_likes	|-15.727551|
# |avg_offers	|-85.360935|
#
# For every increase by 1 in average number of requests, the model predicts daily average exchanges to increase by 85.
#
# <table><tr><td><img src="../images/dist_190303_174431.png"></td><td><img src="../images/prob_190303_174431.png"></td></tr></table>
#
#
# ---

# %% [markdown]
# ### Model ID: 190303_174354 - ACTIVE timebanks
# #### Selected model
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)
#
# #### Features
# ['const', 'phone', 'facebook', 'mission_word_count', 'avg_offers', 'avg_requests', 'offer_request_ratio', 'members_starting', 'members_daily_new', 'facebook_likes', 'twitter_tweets', 'categories_total', 'categories_with_requests']
#
# |Metric|Value|
# |-----|-----|
# |**Training R2**|0.60239|
# |**Testing R2**|-2.53460|
# |**Explained variance**|-2.43792|
# |**Mean absolute error (MAE)**|1.59174|
# |**Mean squared error (MSE)**|3.47581|
# |**Root mean squared error (RMSE)**|1.86435|
# |**Median absolute error (MedAE)**|1.59851|
# |**Mean distribution of residuals**|0.30833|
#
#
# <table><tr><td><img src="../images/dist_190303_174354.png"></td><td><img src="../images/prob_190303_174354.png"></td></tr></table>
#
#
# ---

# %% [markdown]
# ### Model ID: 190303_174312 - ACTIVE timebanks
# #### Selected model
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)
#
# #### Features
# ['const', 'phone', 'facebook', 'mission_word_count', 'avg_offers', 'avg_requests', 'offer_request_ratio', 'members_starting', 'members_daily_new', 'facebook_followers', 'twitter_tweets', 'categories_total', 'categories_with_requests']
#
# |Metric|Value|
# |-----|-----|
# |**Training R2**|0.59740|
# |**Testing R2**|-2.56748|
# |**Explained variance**|-2.47653|
# |**Mean absolute error (MAE)**|1.59523|
# |**Mean squared error (MSE)**|3.50814|
# |**Root mean squared error (RMSE)**|1.87300|
# |**Median absolute error (MedAE)**|1.58698|
# |**Mean distribution of residuals**|0.29906|
#
#
# <table><tr><td><img src="../images/dist_190303_174312.png"></td><td><img src="../images/prob_190303_174312.png"></td></tr></table>
#
#
# ---

# %% [markdown]
# ### Model ID: 190303_174236 - ACTIVE timebanks
# #### Selected model
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)
#
# #### Features
# ['const', 'phone', 'facebook', 'mission_word_count', 'avg_offers', 'avg_requests', 'offer_request_ratio', 'members_starting', 'members_daily_new', 'facebook_likes', 'facebook_followers', 'twitter_tweets', 'categories_total', 'categories_with_requests']
#
# |Metric|Value|
# |-----|-----|
# |**Training R2**|0.64854|
# |**Testing R2**|-1.74769|
# |**Explained variance**|-1.55469|
# |**Mean absolute error (MAE)**|1.35676|
# |**Mean squared error (MSE)**|2.70199|
# |**Root mean squared error (RMSE)**|1.64377|
# |**Median absolute error (MedAE)**|1.34471|
# |**Mean distribution of residuals**|0.43565|
#
#
# <table><tr><td><img src="../images/dist_190303_174236.png"></td><td><img src="../images/prob_190303_174236.png"></td></tr></table>
#
#
# ---

# %% [markdown]
# ### Model ID: 190303_174153 - ACTIVE timebanks
# #### Selected model
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)
#
# #### Features
# ['const', 'phone', 'facebook', 'mission_word_count', 'avg_offers', 'avg_requests', 'offer_request_ratio', 'members_starting', 'members_daily_new', 'facebook_likes', 'facebook_followers', 'twitter_tweets', 'categories_total', 'categories_with_offers', 'categories_with_requests']
#
# |Metric|Value|
# |-----|-----|
# |**Training R2**|0.64869|
# |**Testing R2**|-1.76173|
# |**Explained variance**|-1.53542|
# |**Mean absolute error (MAE)**|1.37497|
# |**Mean squared error (MSE)**|2.71580|
# |**Root mean squared error (RMSE)**|1.64797|
# |**Median absolute error (MedAE)**|1.37806|
# |**Mean distribution of residuals**|0.47175|
#
#
# <table><tr><td><img src="../images/dist_190303_174153.png"></td><td><img src="../images/prob_190303_174153.png"></td></tr></table>
#
#
# ---

# %% [markdown]
# ### Model ID: 190303_174104 - ACTIVE timebanks
# #### Selected model
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)
#
# #### Features
# ['const', 'phone', 'facebook', 'mission_word_count', 'avg_offers', 'avg_requests', 'offer_request_ratio', 'members_starting', 'members_daily_new', 'facebook_likes', 'facebook_followers', 'twitter_tweets', 'categories_with_offers', 'categories_with_requests', 'talent_per_cat_per_member']
#
# |Metric|Value|
# |-----|-----|
# |**Training R2**|0.64871|
# |**Testing R2**|-1.77984|
# |**Explained variance**|-1.55416|
# |**Mean absolute error (MAE)**|1.37433|
# |**Mean squared error (MSE)**|2.73361|
# |**Root mean squared error (RMSE)**|1.65336|
# |**Median absolute error (MedAE)**|1.37541|
# |**Mean distribution of residuals**|0.47109|
#
#
# <table><tr><td><img src="../images/dist_190303_174104.png"></td><td><img src="../images/prob_190303_174104.png"></td></tr></table>
#
#
# ---

# %% [markdown]
# ### Model ID: 190303_174031 - ACTIVE timebanks
# #### Selected model
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)
#
# #### Features
# ['const', 'facebook', 'mission_word_count', 'avg_offers', 'avg_requests', 'offer_request_ratio', 'members_starting', 'members_daily_new', 'facebook_likes', 'facebook_followers', 'twitter_tweets', 'categories_total', 'categories_with_offers', 'categories_with_requests', 'talent_per_cat_per_member']
#
# |Metric|Value|
# |-----|-----|
# |**Training R2**|0.63677|
# |**Testing R2**|-1.88138|
# |**Explained variance**|-1.79659|
# |**Mean absolute error (MAE)**|1.42238|
# |**Mean squared error (MSE)**|2.83345|
# |**Root mean squared error (RMSE)**|1.68329|
# |**Median absolute error (MedAE)**|1.33229|
# |**Mean distribution of residuals**|0.28876|
#
#
# <table><tr><td><img src="../images/dist_190303_174031.png"></td><td><img src="../images/prob_190303_174031.png"></td></tr></table>
#
#
# ---

# %% [markdown]
# ### Model ID: 190303_173951 - ACTIVE timebanks
# #### Selected model
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)
#
# #### Features
# ['const', 'phone', 'facebook', 'avg_offers', 'avg_requests', 'offer_request_ratio', 'members_starting', 'members_daily_new', 'facebook_likes', 'facebook_followers', 'twitter_tweets', 'categories_total', 'categories_with_offers', 'categories_with_requests', 'talent_per_cat_per_member']
#
# |Metric|Value|
# |-----|-----|
# |**Training R2**|0.64862|
# |**Testing R2**|-1.82558|
# |**Explained variance**|-1.52973|
# |**Mean absolute error (MAE)**|1.42416|
# |**Mean squared error (MSE)**|2.77858|
# |**Root mean squared error (RMSE)**|1.66691|
# |**Median absolute error (MedAE)**|1.41318|
# |**Mean distribution of residuals**|0.53938|
#
#
# <table><tr><td><img src="../images/dist_190303_173951.png"></td><td><img src="../images/prob_190303_173951.png"></td></tr></table>
#
#
# ---

# %% [markdown]
# ### Model ID: 190303_173914 - ACTIVE timebanks
# #### Selected model
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)
#
# #### Features
# ['const', 'phone', 'facebook', 'mission_word_count', 'avg_offers', 'avg_requests', 'offer_request_ratio', 'members_starting', 'members_daily_new', 'facebook_likes', 'facebook_followers', 'twitter_tweets', 'categories_total', 'categories_with_offers', 'categories_with_requests', 'talent_per_cat_per_member']
#
# |Metric|Value|
# |-----|-----|
# |**Training R2**|0.64871|
# |**Testing R2**|-1.77966|
# |**Explained variance**|-1.55474|
# |**Mean absolute error (MAE)**|1.37330|
# |**Mean squared error (MSE)**|2.73343|
# |**Root mean squared error (RMSE)**|1.65331|
# |**Median absolute error (MedAE)**|1.37504|
# |**Mean distribution of residuals**|0.47030|
#
#
# <table><tr><td><img src="../images/dist_190303_173914.png"></td><td><img src="../images/prob_190303_173914.png"></td></tr></table>
#
#
# ---

# %% [markdown]
# ### Model ID: 190303_173836 - ACTIVE timebanks
# #### Selected model
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)
#
# #### Features
# ['const', 'phone', 'facebook', 'mission_word_count', 'avg_offers', 'avg_requests', 'offer_request_ratio', 'members_starting', 'members_daily_new', 'facebook_likes', 'facebook_followers', 'twitter_tweets', 'twitter_following', 'categories_total', 'categories_with_offers', 'categories_with_requests', 'talent_per_cat_per_member']
#
# |Metric|Value|
# |-----|-----|
# |**Training R2**|0.65393|
# |**Testing R2**|-2.16610|
# |**Explained variance**|-1.87044|
# |**Mean absolute error (MAE)**|1.46707|
# |**Mean squared error (MSE)**|3.11344|
# |**Root mean squared error (RMSE)**|1.76449|
# |**Median absolute error (MedAE)**|1.39646|
# |**Mean distribution of residuals**|0.53921|
#
#
# <table><tr><td><img src="../images/dist_190303_173836.png"></td><td><img src="../images/prob_190303_173836.png"></td></tr></table>
#
#
# ---

# %% [markdown]
# ### Model ID: 190303_173804 - ACTIVE timebanks
# #### Selected model
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)
#
# #### Features
# ['const', 'phone', 'facebook', 'mission_word_count', 'avg_offers', 'avg_requests', 'offer_request_ratio', 'members_starting', 'members_daily_new', 'facebook_likes', 'facebook_followers', 'twitter_tweets', 'twitter_following', 'twitter_followers', 'categories_total', 'categories_with_offers', 'categories_with_requests', 'talent_per_cat_per_member']
#
# |Metric|Value|
# |-----|-----|
# |**Training R2**|0.69500|
# |**Testing R2**|-2.70876|
# |**Explained variance**|-2.48835|
# |**Mean absolute error (MAE)**|1.59996|
# |**Mean squared error (MSE)**|3.64707|
# |**Root mean squared error (RMSE)**|1.90973|
# |**Median absolute error (MedAE)**|1.55640|
# |**Mean distribution of residuals**|0.46556|
#
#
# <table><tr><td><img src="../images/dist_190303_173804.png"></td><td><img src="../images/prob_190303_173804.png"></td></tr></table>
#
#
# ---

# %% [markdown]
# ### Model ID: 190303_173720 - ACTIVE timebanks
# #### Selected model
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)
#
# #### Features
# ['const', 'phone', 'facebook', 'twitter', 'mission_word_count', 'avg_offers', 'avg_requests', 'offer_request_ratio', 'members_starting', 'members_daily_new', 'facebook_likes', 'facebook_followers', 'twitter_tweets', 'twitter_following', 'twitter_followers', 'categories_total', 'categories_with_offers', 'categories_with_requests', 'talent_per_cat_per_member']
#
# |Metric|Value|
# |-----|-----|
# |**Training R2**|0.69811|
# |**Testing R2**|-3.09305|
# |**Explained variance**|-2.85452|
# |**Mean absolute error (MAE)**|1.66667|
# |**Mean squared error (MSE)**|4.02497|
# |**Root mean squared error (RMSE)**|2.00623|
# |**Median absolute error (MedAE)**|1.50543|
# |**Mean distribution of residuals**|0.48432|
#
#
# <table><tr><td><img src="../images/dist_190303_173720.png"></td><td><img src="../images/prob_190303_173720.png"></td></tr></table>
#
#
# ---

# %% [markdown]
# ### Model ID: 190303_173644 - ACTIVE timebanks
# #### Selected model
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)
#
# #### Features
# ['const', 'phone', 'facebook', 'twitter', 'mission_word_count', 'avg_offers', 'avg_requests', 'offer_request_ratio', 'members_starting', 'members_daily_new', 'facebook_likes', 'facebook_followers', 'twitter_tweets', 'twitter_following', 'twitter_followers', 'categories_total', 'categories_parent', 'categories_with_offers', 'categories_with_requests', 'talent_per_cat_per_member']
#
# |Metric|Value|
# |-----|-----|
# |**Training R2**|0.69826|
# |**Testing R2**|-3.12820|
# |**Explained variance**|-2.91172|
# |**Mean absolute error (MAE)**|1.67817|
# |**Mean squared error (MSE)**|4.05953|
# |**Root mean squared error (RMSE)**|2.01483|
# |**Median absolute error (MedAE)**|1.55361|
# |**Mean distribution of residuals**|0.46138|
#
#
# <table><tr><td><img src="../images/dist_190303_173644.png"></td><td><img src="../images/prob_190303_173644.png"></td></tr></table>
#
#
# ---

# %% [markdown]
# ### Model ID: 190303_173607 - ACTIVE timebanks
# #### Selected model
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)
#
# #### Features
# ['const', 'phone', 'facebook', 'twitter', 'mission_word_count', 'mission_sentiment', 'avg_offers', 'avg_requests', 'offer_request_ratio', 'members_starting', 'members_daily_new', 'facebook_likes', 'facebook_followers', 'twitter_following', 'twitter_followers', 'categories_total', 'categories_parent', 'categories_with_offers', 'categories_with_requests', 'talent_per_cat_per_member']
#
# |Metric|Value|
# |-----|-----|
# |**Training R2**|0.70564|
# |**Testing R2**|-9.54168|
# |**Explained variance**|-8.38094|
# |**Mean absolute error (MAE)**|2.19835|
# |**Mean squared error (MSE)**|10.36635|
# |**Root mean squared error (RMSE)**|3.21968|
# |**Median absolute error (MedAE)**|1.79005|
# |**Mean distribution of residuals**|1.06838|
#
#
# <table><tr><td><img src="../images/dist_190303_173607.png"></td><td><img src="../images/prob_190303_173607.png"></td></tr></table>
#
#
# ---

# %% [markdown]
# ### Model ID: 190303_173527 - ACTIVE timebanks
# #### Selected model
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)
#
# #### Features
# ['const', 'phone', 'facebook', 'twitter', 'mission_word_count', 'mission_sentiment', 'avg_offers', 'avg_requests', 'offer_request_ratio', 'members_starting', 'members_daily_new', 'facebook_likes', 'facebook_followers', 'twitter_tweets', 'twitter_following', 'twitter_followers', 'categories_total', 'categories_parent', 'categories_with_offers', 'categories_with_requests', 'talent_per_cat_per_member']
#
# |Metric|Value|
# |-----|-----|
# |**Training R2**|0.73781|
# |**Testing R2**|-6.64485|
# |**Explained variance**|-5.49643|
# |**Mean absolute error (MAE)**|2.06972|
# |**Mean squared error (MSE)**|7.51769|
# |**Root mean squared error (RMSE)**|2.74184|
# |**Median absolute error (MedAE)**|1.78718|
# |**Mean distribution of residuals**|1.06269|
#
#
# <table><tr><td><img src="../images/dist_190303_173527.png"></td><td><img src="../images/prob_190303_173527.png"></td></tr></table>
#
#
# ---

# %% [markdown]
# ### Model ID: 190303_173448 - ACTIVE timebanks
# #### Selected model
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)
#
# #### Features
# ['const', 'phone', 'facebook', 'twitter', 'mission_word_count', 'mission_sentiment', 'hours_per_exchange', 'avg_offers', 'avg_requests', 'offer_request_ratio', 'members_starting', 'facebook_likes', 'facebook_followers', 'twitter_tweets', 'twitter_following', 'twitter_followers', 'categories_total', 'categories_parent', 'categories_with_offers', 'categories_with_requests', 'talent_per_cat_per_member']
#
# |Metric|Value|
# |-----|-----|
# |**Training R2**|0.73915|
# |**Testing R2**|-9.93501|
# |**Explained variance**|-8.15353|
# |**Mean absolute error (MAE)**|2.31649|
# |**Mean squared error (MSE)**|10.75313|
# |**Root mean squared error (RMSE)**|3.27920|
# |**Median absolute error (MedAE)**|1.95437|
# |**Mean distribution of residuals**|1.32358|
#
#
# <table><tr><td><img src="../images/dist_190303_173448.png"></td><td><img src="../images/prob_190303_173448.png"></td></tr></table>
#
#
# ---

# %% [markdown]
# ### Model ID: 190303_173303 - ACTIVE timebanks
# #### Selected model
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)
#
# #### Features
# ['const', 'phone', 'facebook', 'twitter', 'mission_word_count', 'mission_sentiment', 'hours_per_exchange', 'avg_offers', 'offer_request_ratio', 'members_starting', 'members_daily_new', 'facebook_likes', 'facebook_followers', 'twitter_tweets', 'twitter_following', 'twitter_followers', 'categories_total', 'categories_parent', 'categories_with_offers', 'categories_with_requests', 'talent_per_cat_per_member']
#
# |Metric|Value|
# |-----|-----|
# |**Training R2**|0.68895|
# |**Testing R2**|-14.69608|
# |**Explained variance**|-13.64680|
# |**Mean absolute error (MAE)**|2.43657|
# |**Mean squared error (MSE)**|15.43501|
# |**Root mean squared error (RMSE)**|3.92874|
# |**Median absolute error (MedAE)**|1.93943|
# |**Mean distribution of residuals**|1.01579|
#
#
# <table><tr><td><img src="../images/dist_190303_173303.png"></td><td><img src="../images/prob_190303_173303.png"></td></tr></table>
#
#
# ---

# %% [markdown]
# ### Model ID: 190303_173209 - ACTIVE timebanks
# #### Selected model
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)
#
# #### Features
# ['const', 'phone', 'facebook', 'twitter', 'mission_word_count', 'mission_sentiment', 'hours_per_exchange', 'avg_requests', 'offer_request_ratio', 'members_starting', 'members_daily_new', 'facebook_likes', 'facebook_followers', 'twitter_tweets', 'twitter_following', 'twitter_followers', 'categories_total', 'categories_parent', 'categories_with_offers', 'categories_with_requests', 'talent_per_cat_per_member']
#
# |Metric|Value|
# |-----|-----|
# |**Training R2**|0.68873|
# |**Testing R2**|-14.88304|
# |**Explained variance**|-13.81724|
# |**Mean absolute error (MAE)**|2.44565|
# |**Mean squared error (MSE)**|15.61886|
# |**Root mean squared error (RMSE)**|3.95207|
# |**Median absolute error (MedAE)**|1.93823|
# |**Mean distribution of residuals**|1.02375|
#
#
# <table><tr><td><img src="../images/dist_190303_173209.png"></td><td><img src="../images/prob_190303_173209.png"></td></tr></table>
#
#
# ---

# %% [markdown]
# ### Model ID: 190303_173125 - ACTIVE timebanks
# #### Selected model
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)
#
# #### Features
# ['const', 'phone', 'facebook', 'twitter', 'mission_word_count', 'mission_sentiment', 'hours_per_exchange', 'avg_offers', 'avg_requests', 'offer_request_ratio', 'members_starting', 'members_daily_new', 'facebook_likes', 'facebook_followers', 'twitter_tweets', 'twitter_following', 'twitter_followers', 'categories_total', 'categories_parent', 'categories_with_offers', 'categories_with_requests', 'talent_per_cat_per_member']
#
# |Metric|Value|
# |-----|-----|
# |**Training R2**|0.74976|
# |**Testing R2**|-7.38661|
# |**Explained variance**|-5.93627|
# |**Mean absolute error (MAE)**|2.15242|
# |**Mean squared error (MSE)**|8.24712|
# |**Root mean squared error (RMSE)**|2.87178|
# |**Median absolute error (MedAE)**|1.90348|
# |**Mean distribution of residuals**|1.19425|
#
#
# <table><tr><td><img src="../images/dist_190303_173125.png"></td><td><img src="../images/prob_190303_173125.png"></td></tr></table>
#
#
# ---

# %% [markdown]
# ### Model ID: 190303_173046 - ACTIVE timebanks
# #### Selected model
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)
#
# #### Features
# ['const', 'sponsor', 'phone', 'facebook', 'twitter', 'mission_word_count', 'mission_sentiment', 'hours_per_exchange', 'avg_offers', 'avg_requests', 'offer_request_ratio', 'members_starting', 'members_daily_new', 'facebook_likes', 'facebook_followers', 'twitter_tweets', 'twitter_following', 'twitter_followers', 'categories_total', 'categories_parent', 'categories_with_offers', 'categories_with_requests', 'talent_per_cat_per_member']
#
# |Metric|Value|
# |-----|-----|
# |**Training R2**|0.78204|
# |**Testing R2**|-9.46300|
# |**Explained variance**|-7.88831|
# |**Mean absolute error (MAE)**|2.48559|
# |**Mean squared error (MSE)**|10.28897|
# |**Root mean squared error (RMSE)**|3.20764|
# |**Median absolute error (MedAE)**|2.58847|
# |**Mean distribution of residuals**|1.24439|
#
#
# <table><tr><td><img src="../images/dist_190303_173046.png"></td><td><img src="../images/prob_190303_173046.png"></td></tr></table>
#
#
# ---

# %% [markdown]
# ### Model ID: 190303_172955 - ACTIVE timebanks
# #### Selected model
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)
#
# #### Features
# ['const', 'sponsor', 'phone', 'facebook', 'twitter', 'mission_word_count', 'mission_sentiment', 'notes_word_count', 'hours_per_exchange', 'avg_offers', 'avg_requests', 'offer_request_ratio', 'members_starting', 'members_daily_new', 'facebook_likes', 'facebook_followers', 'twitter_tweets', 'twitter_following', 'twitter_followers', 'categories_total', 'categories_parent', 'categories_with_offers', 'categories_with_requests', 'talent_per_cat_per_member']
#
# |Metric|Value|
# |-----|-----|
# |**Training R2**|0.80715|
# |**Testing R2**|-13.44977|
# |**Explained variance**|-10.54401|
# |**Mean absolute error (MAE)**|3.01699|
# |**Mean squared error (MSE)**|14.20943|
# |**Root mean squared error (RMSE)**|3.76954|
# |**Median absolute error (MedAE)**|2.56512|
# |**Mean distribution of residuals**|1.69039|
#
#
# <table><tr><td><img src="../images/dist_190303_172955.png"></td><td><img src="../images/prob_190303_172955.png"></td></tr></table>
#
#
# ---

# %% [markdown]
# ### Model ID: 190303_172916 - ACTIVE timebanks
# #### Selected model
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)
#
# #### Features
# ['const', 'sponsor', 'phone', 'url_2', 'facebook', 'twitter', 'mission_word_count', 'mission_sentiment', 'notes_word_count', 'hours_per_exchange', 'avg_offers', 'avg_requests', 'members_starting', 'members_daily_new', 'facebook_likes', 'facebook_followers', 'twitter_tweets', 'twitter_following', 'twitter_followers', 'categories_total', 'categories_parent', 'categories_with_offers', 'categories_with_requests', 'talent_per_cat_per_member']
#
# |Metric|Value|
# |-----|-----|
# |**Training R2**|0.81010|
# |**Testing R2**|-18.91505|
# |**Explained variance**|-15.02054|
# |**Mean absolute error (MAE)**|3.38782|
# |**Mean squared error (MSE)**|19.58381|
# |**Root mean squared error (RMSE)**|4.42536|
# |**Median absolute error (MedAE)**|2.78032|
# |**Mean distribution of residuals**|1.95697|
#
#
# <table><tr><td><img src="../images/dist_190303_172916.png"></td><td><img src="../images/prob_190303_172916.png"></td></tr></table>
#
#
# ---

# %% [markdown]
# ### Model ID: 190303_172832 - ACTIVE timebanks
# #### Selected model
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)
#
# #### Features
# ['const', 'sponsor', 'phone', 'url_2', 'facebook', 'twitter', 'mission_word_count', 'mission_sentiment', 'notes_word_count', 'hours_per_exchange', 'avg_offers', 'avg_requests', 'offer_request_ratio', 'members_starting', 'members_daily_new', 'facebook_likes', 'facebook_followers', 'twitter_tweets', 'twitter_following', 'twitter_followers', 'categories_total', 'categories_parent', 'categories_with_offers', 'categories_with_requests', 'talent_per_cat_per_member']
#
# |Metric|Value|
# |-----|-----|
# |**Training R2**|0.81285|
# |**Testing R2**|-16.30944|
# |**Explained variance**|-12.72225|
# |**Mean absolute error (MAE)**|3.19101|
# |**Mean squared error (MSE)**|17.02154|
# |**Root mean squared error (RMSE)**|4.12572|
# |**Median absolute error (MedAE)**|2.57987|
# |**Mean distribution of residuals**|1.87817|
#
#
# <table><tr><td><img src="../images/dist_190303_172832.png"></td><td><img src="../images/prob_190303_172832.png"></td></tr></table>
#
#
# ---

# %% [markdown]
# ### Model ID: 190303_172742 - ACTIVE timebanks
# #### Selected model
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)
#
# #### Features
# ['const', 'sponsor', 'phone', 'url_2', 'facebook', 'twitter', 'mission_word_count', 'mission_sentiment', 'notes_word_count', 'notes_sentiment', 'hours_per_exchange', 'avg_offers', 'avg_requests', 'offer_request_ratio', 'members_starting', 'members_daily_new', 'facebook_likes', 'facebook_followers', 'twitter_tweets', 'twitter_following', 'twitter_followers', 'categories_total', 'categories_parent', 'categories_with_offers', 'categories_with_requests', 'talent_per_cat_per_member']
#
# |Metric|Value|
# |-----|-----|
# |**Training R2**|-1.68962|
# |**Testing R2**|-616.00415|
# |**Explained variance**|-527.18428|
# |**Mean absolute error (MAE)**|11.43300|
# |**Mean squared error (MSE)**|606.74164|
# |**Root mean squared error (RMSE)**|24.63213|
# |**Median absolute error (MedAE)**|4.30921|
# |**Mean distribution of residuals**|9.34572|
#
#
# <table><tr><td><img src="../images/dist_190303_172742.png"></td><td><img src="../images/prob_190303_172742.png"></td></tr></table>
#
#
# ---

# %% [markdown]
# ## Linear Regression for ALL Timebanks

# %% [markdown]
# ### Model ID: 190303_165201 - ALL timebanks
# #### Selected model
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)
#
# #### Features
# ['const', 'sponsor', 'phone', 'url_2', 'mission_word_count', 'mission_sentiment', 'notes_sentiment', 'members_starting', 'members_daily_new', 'facebook_likes', 'facebook_followers', 'twitter_tweets', 'twitter_following', 'twitter_followers', 'categories_total', 'categories_parent', 'talent_per_cat_per_member']
#
# |Metric|Value|
# |-----|-----|
# |**Training R2**|0.46797|
# |**Testing R2**|-0.28399|
# |**Explained variance**|-0.28362|
# |**Mean absolute error (MAE)**|0.72856|
# |**Mean squared error (MSE)**|1.99916|
# |**Root mean squared error (RMSE)**|1.41392|
# |**Median absolute error (MedAE)**|0.44109|
# |**Mean distribution of residuals**|-0.02386|
#
#
# <table><tr><td><img src="../images/dist_190303_165201.png"></td><td><img src="../images/prob_190303_165201.png"></td></tr></table>
#
#
# ---

# %% [markdown]
# ### Model ID: 190303_165059 - ALL timebanks
# #### Selected model
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)
#
# #### Features
# ['const', 'sponsor', 'phone', 'url_2', 'mission_word_count', 'mission_sentiment', 'notes_sentiment', 'members_daily_new', 'facebook_likes', 'facebook_followers', 'twitter_tweets', 'twitter_following', 'twitter_followers', 'categories_total', 'categories_parent', 'categories_with_requests', 'talent_per_cat_per_member']
#
# |Metric|Value|
# |-----|-----|
# |**Training R2**|0.41702|
# |**Testing R2**|-0.47799|
# |**Explained variance**|-0.45570|
# |**Mean absolute error (MAE)**|0.81420|
# |**Mean squared error (MSE)**|2.30122|
# |**Root mean squared error (RMSE)**|1.51698|
# |**Median absolute error (MedAE)**|0.56473|
# |**Mean distribution of residuals**|0.18629|
#
#
# <table><tr><td><img src="../images/dist_190303_165059.png"></td><td><img src="../images/prob_190303_165059.png"></td></tr></table>
#
#
# ---

# %% [markdown]
# ### Model ID: 190303_165008 - ALL timebanks
# #### Selected model
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)
#
# #### Features
# ['const', 'sponsor', 'phone', 'url_2', 'mission_word_count', 'mission_sentiment', 'notes_sentiment', 'members_starting', 'members_daily_new', 'facebook_likes', 'facebook_followers', 'twitter_tweets', 'twitter_following', 'twitter_followers', 'categories_total', 'categories_parent', 'categories_with_requests', 'talent_per_cat_per_member']
#
# |Metric|Value|
# |-----|-----|
# |**Training R2**|0.54122|
# |**Testing R2**|0.03987|
# |**Explained variance**|0.04020|
# |**Mean absolute error (MAE)**|0.66042|
# |**Mean squared error (MSE)**|1.49491|
# |**Root mean squared error (RMSE)**|1.22267|
# |**Median absolute error (MedAE)**|0.38772|
# |**Mean distribution of residuals**|0.02262|
#
#
# <table><tr><td><img src="../images/dist_190303_165008.png"></td><td><img src="../images/prob_190303_165008.png"></td></tr></table>
#
#
# ---

# %% [markdown]
# ### Model ID: 190303_164924 - ALL timebanks
# #### Selected model
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)
#
# #### Features
# ['const', 'sponsor', 'phone', 'url_2', 'mission_word_count', 'mission_sentiment', 'notes_sentiment', 'members_starting', 'members_daily_new', 'facebook_likes', 'facebook_followers', 'twitter_tweets', 'twitter_following', 'twitter_followers', 'categories_parent', 'categories_with_offers', 'categories_with_requests', 'talent_per_cat_per_member']
#
# |Metric|Value|
# |-----|-----|
# |**Training R2**|0.54686|
# |**Testing R2**|-0.03043|
# |**Explained variance**|-0.02979|
# |**Mean absolute error (MAE)**|0.68899|
# |**Mean squared error (MSE)**|1.60438|
# |**Root mean squared error (RMSE)**|1.26664|
# |**Median absolute error (MedAE)**|0.40383|
# |**Mean distribution of residuals**|0.03160|
#
#
# <table><tr><td><img src="../images/dist_190303_164924.png"></td><td><img src="../images/prob_190303_164924.png"></td></tr></table>
#
#
# ---

# %% [markdown]
# ### Model ID: 190303_164804 - ALL timebanks
# #### Selected model
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)
#
# #### Features
# ['const', 'sponsor', 'phone', 'url_2', 'mission_word_count', 'mission_sentiment', 'notes_sentiment', 'members_starting', 'members_daily_new', 'facebook_likes', 'facebook_followers', 'twitter_tweets', 'twitter_following', 'twitter_followers', 'categories_total', 'categories_parent', 'categories_with_offers', 'categories_with_requests', 'talent_per_cat_per_member']
#
# |Metric|Value|
# |-----|-----|
# |**Training R2**|0.54788|
# |**Testing R2**|-0.00523|
# |**Explained variance**|-0.00482|
# |**Mean absolute error (MAE)**|0.67865|
# |**Mean squared error (MSE)**|1.56514|
# |**Root mean squared error (RMSE)**|1.25106|
# |**Median absolute error (MedAE)**|0.37746|
# |**Mean distribution of residuals**|0.02537|
#
#
# <table><tr><td><img src="../images/dist_190303_164804.png"></td><td><img src="../images/prob_190303_164804.png"></td></tr></table>
#
#
# ---

# %% [markdown]
# ### Model ID: 190303_164723 - ALL timebanks
# #### Selected model
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)
#
# #### Features
# ['const', 'sponsor', 'phone', 'url_2', 'facebook', 'mission_word_count', 'mission_sentiment', 'notes_sentiment', 'members_starting', 'members_daily_new', 'facebook_followers', 'twitter_tweets', 'twitter_following', 'twitter_followers', 'categories_total', 'categories_parent', 'categories_with_offers', 'categories_with_requests', 'talent_per_cat_per_member']
#
# |Metric|Value|
# |-----|-----|
# |**Training R2**|0.54168|
# |**Testing R2**|-0.04916|
# |**Explained variance**|-0.04901|
# |**Mean absolute error (MAE)**|0.68076|
# |**Mean squared error (MSE)**|1.63353|
# |**Root mean squared error (RMSE)**|1.27810|
# |**Median absolute error (MedAE)**|0.36710|
# |**Mean distribution of residuals**|-0.01491|
#
#
# <table><tr><td><img src="../images/dist_190303_164723.png"></td><td><img src="../images/prob_190303_164723.png"></td></tr></table>
#
#
# ---

# %% [markdown]
# ### Model ID: 190303_164641 - ALL timebanks
# #### Selected model
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)
#
# #### Features
# ['const', 'sponsor', 'phone', 'url_2', 'facebook', 'mission_word_count', 'mission_sentiment', 'notes_sentiment', 'members_starting', 'members_daily_new', 'facebook_likes', 'twitter_tweets', 'twitter_following', 'twitter_followers', 'categories_total', 'categories_parent', 'categories_with_offers', 'categories_with_requests', 'talent_per_cat_per_member']
#
# |Metric|Value|
# |-----|-----|
# |**Training R2**|0.54165|
# |**Testing R2**|-0.04816|
# |**Explained variance**|-0.04801|
# |**Mean absolute error (MAE)**|0.68089|
# |**Mean squared error (MSE)**|1.63197|
# |**Root mean squared error (RMSE)**|1.27749|
# |**Median absolute error (MedAE)**|0.36707|
# |**Mean distribution of residuals**|-0.01482|
#
#
# <table><tr><td><img src="../images/dist_190303_164641.png"></td><td><img src="../images/prob_190303_164641.png"></td></tr></table>
#
#
# ---

# %% [markdown]
# ### Model ID: 190303_164556 - ALL timebanks
# #### Selected model
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)
#
# #### Features
# ['const', 'sponsor', 'phone', 'url_2', 'facebook', 'mission_word_count', 'mission_sentiment', 'notes_sentiment', 'members_starting', 'members_daily_new', 'facebook_likes', 'facebook_followers', 'twitter_tweets', 'twitter_following', 'twitter_followers', 'categories_total', 'categories_parent', 'categories_with_offers', 'categories_with_requests']
#
# |Metric|Value|
# |-----|-----|
# |**Training R2**|0.53162|
# |**Testing R2**|-0.07859|
# |**Explained variance**|-0.07626|
# |**Mean absolute error (MAE)**|0.72080|
# |**Mean squared error (MSE)**|1.67936|
# |**Root mean squared error (RMSE)**|1.29590|
# |**Median absolute error (MedAE)**|0.48811|
# |**Mean distribution of residuals**|0.06029|
#
#
# <table><tr><td><img src="../images/dist_190303_164556.png"></td><td><img src="../images/prob_190303_164556.png"></td></tr></table>
#
#
# ---

# %% [markdown]
# ### Model ID: 190303_164509 - ALL timebanks
# #### Selected model
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)
#
# #### Features
# ['const', 'sponsor', 'phone', 'url_2', 'facebook', 'mission_word_count', 'mission_sentiment', 'notes_sentiment', 'members_starting', 'members_daily_new', 'facebook_likes', 'facebook_followers', 'twitter_tweets', 'twitter_following', 'twitter_followers', 'categories_total', 'categories_with_offers', 'categories_with_requests', 'talent_per_cat_per_member']
#
# |Metric|Value|
# |-----|-----|
# |**Training R2**|0.54807|
# |**Testing R2**|-0.00810|
# |**Explained variance**|-0.00772|
# |**Mean absolute error (MAE)**|0.68468|
# |**Mean squared error (MSE)**|1.56961|
# |**Root mean squared error (RMSE)**|1.25284|
# |**Median absolute error (MedAE)**|0.38013|
# |**Mean distribution of residuals**|0.02432|
#
#
# <table><tr><td><img src="../images/dist_190303_164509.png"></td><td><img src="../images/prob_190303_164509.png"></td></tr></table>
#
#
# ---

# %% [markdown]
# ### Model ID: 190303_164407 - ALL timebanks
# #### Selected model
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)
#
# #### Features
# ['const', 'sponsor', 'phone', 'url_2', 'facebook', 'mission_word_count', 'mission_sentiment', 'notes_sentiment', 'members_starting', 'members_daily_new', 'facebook_likes', 'facebook_followers', 'twitter_tweets', 'twitter_following', 'twitter_followers', 'categories_total', 'categories_parent', 'categories_with_offers', 'categories_with_requests', 'talent_per_cat_per_member']
#
# |Metric|Value|
# |-----|-----|
# |**Training R2**|0.54811|
# |**Testing R2**|-0.00747|
# |**Explained variance**|-0.00710|
# |**Mean absolute error (MAE)**|0.68335|
# |**Mean squared error (MSE)**|1.56863|
# |**Root mean squared error (RMSE)**|1.25245|
# |**Median absolute error (MedAE)**|0.36951|
# |**Mean distribution of residuals**|0.02398|
#
#
# <table><tr><td><img src="../images/dist_190303_164407.png"></td><td><img src="../images/prob_190303_164407.png"></td></tr></table>
#
#
# ---

# %% [markdown]
# ### Model ID: 190303_164315 - ALL timebanks
# #### Selected model
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)
#
# #### Features
# ['const', 'sponsor', 'phone', 'url_2', 'facebook', 'mission_sentiment', 'notes_sentiment', 'offer_request_ratio', 'members_starting', 'members_daily_new', 'facebook_likes', 'facebook_followers', 'twitter_tweets', 'twitter_following', 'twitter_followers', 'categories_total', 'categories_parent', 'categories_with_offers', 'categories_with_requests', 'talent_per_cat_per_member']
#
# |Metric|Value|
# |-----|-----|
# |**Training R2**|0.54895|
# |**Testing R2**|-0.04810|
# |**Explained variance**|-0.04810|
# |**Mean absolute error (MAE)**|0.68334|
# |**Mean squared error (MSE)**|1.63188|
# |**Root mean squared error (RMSE)**|1.27745|
# |**Median absolute error (MedAE)**|0.32604|
# |**Mean distribution of residuals**|-0.00183|
#
#
# <table><tr><td><img src="../images/dist_190303_164315.png"></td><td><img src="../images/prob_190303_164315.png"></td></tr></table>
#
#
# ---

# %% [markdown]
# ### Model ID: 190303_164231 - ALL timebanks
# #### Selected model
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)
#
# #### Features
# ['const', 'sponsor', 'phone', 'url_2', 'facebook', 'mission_word_count', 'notes_sentiment', 'offer_request_ratio', 'members_starting', 'members_daily_new', 'facebook_likes', 'facebook_followers', 'twitter_tweets', 'twitter_following', 'twitter_followers', 'categories_total', 'categories_parent', 'categories_with_offers', 'categories_with_requests', 'talent_per_cat_per_member']
#
# |Metric|Value|
# |-----|-----|
# |**Training R2**|0.55376|
# |**Testing R2**|-0.03346|
# |**Explained variance**|-0.03311|
# |**Mean absolute error (MAE)**|0.67866|
# |**Mean squared error (MSE)**|1.60908|
# |**Root mean squared error (RMSE)**|1.26850|
# |**Median absolute error (MedAE)**|0.33992|
# |**Mean distribution of residuals**|0.02335|
#
#
# <table><tr><td><img src="../images/dist_190303_164231.png"></td><td><img src="../images/prob_190303_164231.png"></td></tr></table>
#
#
# ---

# %% [markdown]
# ### Model ID: 190303_164123 - ALL timebanks
# #### Selected model
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)
#
# #### Features
# ['const', 'sponsor', 'phone', 'url_2', 'facebook', 'mission_word_count', 'mission_sentiment', 'notes_sentiment', 'offer_request_ratio', 'members_starting', 'members_daily_new', 'facebook_likes', 'facebook_followers', 'twitter_tweets', 'twitter_following', 'twitter_followers', 'categories_total', 'categories_parent', 'categories_with_offers', 'categories_with_requests', 'talent_per_cat_per_member']
#
# |Metric|Value|
# |-----|-----|
# |**Training R2**|0.55376|
# |**Testing R2**|-0.03286|
# |**Explained variance**|-0.03250|
# |**Mean absolute error (MAE)**|0.67816|
# |**Mean squared error (MSE)**|1.60816|
# |**Root mean squared error (RMSE)**|1.26813|
# |**Median absolute error (MedAE)**|0.33739|
# |**Mean distribution of residuals**|0.02351|
#
#
# <table><tr><td><img src="../images/dist_190303_164123.png"></td><td><img src="../images/prob_190303_164123.png"></td></tr></table>
#
#
# ---

# %% [markdown]
# ### Model ID: 190303_164036 - ALL timebanks
# #### Selected model
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)
#
# #### Features
# ['const', 'sponsor', 'phone', 'url_2', 'facebook', 'mission_word_count', 'mission_sentiment', 'notes_sentiment', 'hours_per_exchange', 'offer_request_ratio', 'members_starting', 'members_daily_new', 'facebook_likes', 'facebook_followers', 'twitter_tweets', 'twitter_following', 'categories_total', 'categories_parent', 'categories_with_offers', 'categories_with_requests', 'talent_per_cat_per_member']
#
# |Metric|Value|
# |-----|-----|
# |**Training R2**|0.55473|
# |**Testing R2**|-1.82801|
# |**Explained variance**|-1.80911|
# |**Mean absolute error (MAE)**|0.95339|
# |**Mean squared error (MSE)**|4.40320|
# |**Root mean squared error (RMSE)**|2.09838|
# |**Median absolute error (MedAE)**|0.40112|
# |**Mean distribution of residuals**|-0.17154|
#
#
# <table><tr><td><img src="../images/dist_190303_164036.png"></td><td><img src="../images/prob_190303_164036.png"></td></tr></table>
#
#
# ---

# %% [markdown]
# ### Model ID: 190303_163952 - ALL timebanks
# #### Selected model
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)
#
# #### Features
# ['const', 'sponsor', 'phone', 'url_2', 'facebook', 'mission_word_count', 'mission_sentiment', 'notes_sentiment', 'hours_per_exchange', 'offer_request_ratio', 'members_starting', 'members_daily_new', 'facebook_likes', 'facebook_followers', 'twitter_following', 'twitter_followers', 'categories_total', 'categories_parent', 'categories_with_offers', 'categories_with_requests', 'talent_per_cat_per_member']
#
# |Metric|Value|
# |-----|-----|
# |**Training R2**|0.55725|
# |**Testing R2**|-1.66079|
# |**Explained variance**|-1.61211|
# |**Mean absolute error (MAE)**|0.90684|
# |**Mean squared error (MSE)**|4.14282|
# |**Root mean squared error (RMSE)**|2.03539|
# |**Median absolute error (MedAE)**|0.36812|
# |**Mean distribution of residuals**|-0.27530|
#
#
# <table><tr><td><img src="../images/dist_190303_163952.png"></td><td><img src="../images/prob_190303_163952.png"></td></tr></table>
#
#
# ---

# %% [markdown]
# ### Model ID: 190303_163903 - ALL timebanks
# #### Selected model
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)
#
# #### Features
# ['const', 'sponsor', 'phone', 'url_2', 'facebook', 'mission_word_count', 'mission_sentiment', 'notes_sentiment', 'hours_per_exchange', 'offer_request_ratio', 'members_starting', 'members_daily_new', 'facebook_likes', 'facebook_followers', 'twitter_tweets', 'twitter_following', 'twitter_followers', 'categories_total', 'categories_parent', 'categories_with_offers', 'categories_with_requests', 'talent_per_cat_per_member']
#
# |Metric|Value|
# |-----|-----|
# |**Training R2**|0.56011|
# |**Testing R2**|-1.53489|
# |**Explained variance**|-1.50698|
# |**Mean absolute error (MAE)**|0.90217|
# |**Mean squared error (MSE)**|3.94680|
# |**Root mean squared error (RMSE)**|1.98666|
# |**Median absolute error (MedAE)**|0.38625|
# |**Mean distribution of residuals**|-0.20846|
#
#
# <table><tr><td><img src="../images/dist_190303_163903.png"></td><td><img src="../images/prob_190303_163903.png"></td></tr></table>
#
#
# ---

# %% [markdown]
# ### Model ID: 190303_163816 - ALL timebanks
# #### Selected model
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)
#
# #### Features
# ['const', 'sponsor', 'phone', 'url_2', 'facebook', 'twitter', 'mission_word_count', 'mission_sentiment', 'notes_sentiment', 'hours_per_exchange', 'offer_request_ratio', 'members_starting', 'members_daily_new', 'facebook_likes', 'facebook_followers', 'twitter_tweets', 'twitter_followers', 'categories_total', 'categories_parent', 'categories_with_offers', 'categories_with_requests', 'talent_per_cat_per_member']
#
# |Metric|Value|
# |-----|-----|
# |**Training R2**|0.56330|
# |**Testing R2**|-1.73590|
# |**Explained variance**|-1.69774|
# |**Mean absolute error (MAE)**|0.93320|
# |**Mean squared error (MSE)**|4.25978|
# |**Root mean squared error (RMSE)**|2.06392|
# |**Median absolute error (MedAE)**|0.35406|
# |**Mean distribution of residuals**|-0.24376|
#
#
# <table><tr><td><img src="../images/dist_190303_163816.png"></td><td><img src="../images/prob_190303_163816.png"></td></tr></table>
#
#
# ---

# %% [markdown]
# ### Model ID: 190303_163736 - ALL timebanks
# #### Selected model
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)
#
# #### Features
# ['const', 'sponsor', 'url_2', 'facebook', 'twitter', 'mission_word_count', 'mission_sentiment', 'notes_sentiment', 'hours_per_exchange', 'offer_request_ratio', 'members_starting', 'members_daily_new', 'facebook_likes', 'facebook_followers', 'twitter_tweets', 'twitter_following', 'twitter_followers', 'categories_total', 'categories_parent', 'categories_with_offers', 'categories_with_requests', 'talent_per_cat_per_member']
#
# |Metric|Value|
# |-----|-----|
# |**Training R2**|0.56116|
# |**Testing R2**|-2.05261|
# |**Explained variance**|-2.00608|
# |**Mean absolute error (MAE)**|0.95090|
# |**Mean squared error (MSE)**|4.75290|
# |**Root mean squared error (RMSE)**|2.18011|
# |**Median absolute error (MedAE)**|0.36174|
# |**Mean distribution of residuals**|-0.26918|
#
#
# <table><tr><td><img src="../images/dist_190303_163736.png"></td><td><img src="../images/prob_190303_163736.png"></td></tr></table>
#
#
# ---

# %% [markdown]
# ### Model ID: 190303_163649 - ALL timebanks
# #### Selected model
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)
#
# #### Features
# ['const', 'sponsor', 'phone', 'url_2', 'facebook', 'twitter', 'mission_word_count', 'mission_sentiment', 'notes_sentiment', 'hours_per_exchange', 'offer_request_ratio', 'members_starting', 'members_daily_new', 'facebook_likes', 'facebook_followers', 'twitter_tweets', 'twitter_following', 'twitter_followers', 'categories_total', 'categories_parent', 'categories_with_offers', 'categories_with_requests', 'talent_per_cat_per_member']
#
# |Metric|Value|
# |-----|-----|
# |**Training R2**|0.56458|
# |**Testing R2**|-1.63252|
# |**Explained variance**|-1.59458|
# |**Mean absolute error (MAE)**|0.92222|
# |**Mean squared error (MSE)**|4.09882|
# |**Root mean squared error (RMSE)**|2.02455|
# |**Median absolute error (MedAE)**|0.35594|
# |**Mean distribution of residuals**|-0.24304|
#
#
# <table><tr><td><img src="../images/dist_190303_163649.png"></td><td><img src="../images/prob_190303_163649.png"></td></tr></table>
#
#
# ---

# %% [markdown]
# ### Model ID: 190303_163606 - ALL timebanks
# #### Selected model
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)
#
# #### Features
# ['const', 'sponsor', 'phone', 'url_2', 'facebook', 'twitter', 'mission_word_count', 'mission_sentiment', 'notes_sentiment', 'hours_per_exchange', 'avg_requests', 'offer_request_ratio', 'members_starting', 'facebook_likes', 'facebook_followers', 'twitter_tweets', 'twitter_following', 'twitter_followers', 'categories_total', 'categories_parent', 'categories_with_offers', 'categories_with_requests', 'talent_per_cat_per_member']
#
# |Metric|Value|
# |-----|-----|
# |**Training R2**|0.53539|
# |**Testing R2**|-2.46832|
# |**Explained variance**|-2.38497|
# |**Mean absolute error (MAE)**|0.95773|
# |**Mean squared error (MSE)**|5.40015|
# |**Root mean squared error (RMSE)**|2.32382|
# |**Median absolute error (MedAE)**|0.33969|
# |**Mean distribution of residuals**|-0.36025|
#
#
# <table><tr><td><img src="../images/dist_190303_163606.png"></td><td><img src="../images/prob_190303_163606.png"></td></tr></table>
#
#
# ---

# %% [markdown]
# ### Model ID: 190303_163501 - ALL timebanks
# #### Selected model
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)
#
# #### Features
# ['const', 'sponsor', 'phone', 'url_2', 'facebook', 'twitter', 'mission_word_count', 'mission_sentiment', 'notes_sentiment', 'hours_per_exchange', 'avg_requests', 'offer_request_ratio', 'members_starting', 'members_daily_new', 'facebook_likes', 'facebook_followers', 'twitter_tweets', 'twitter_following', 'twitter_followers', 'categories_total', 'categories_parent', 'categories_with_offers', 'categories_with_requests', 'talent_per_cat_per_member']
#
# |Metric|Value|
# |-----|-----|
# |**Training R2**|0.57709|
# |**Testing R2**|-2.00523|
# |**Explained variance**|-1.95483|
# |**Mean absolute error (MAE)**|0.94390|
# |**Mean squared error (MSE)**|4.67913|
# |**Root mean squared error (RMSE)**|2.16313|
# |**Median absolute error (MedAE)**|0.41461|
# |**Mean distribution of residuals**|-0.28015|
#
#
# <table><tr><td><img src="../images/dist_190303_163501.png"></td><td><img src="../images/prob_190303_163501.png"></td></tr></table>
#
#
# ---

# %% [markdown]
# ### Model ID: 190303_163408 - ALL timebanks
# #### Selected model
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)
#
# #### Features
# ['const', 'phone', 'url_2', 'facebook', 'twitter', 'mission_word_count', 'mission_sentiment', 'notes_sentiment', 'hours_per_exchange', 'avg_offers', 'avg_requests', 'offer_request_ratio', 'members_starting', 'members_daily_new', 'facebook_likes', 'facebook_followers', 'twitter_tweets', 'twitter_following', 'twitter_followers', 'categories_total', 'categories_parent', 'categories_with_offers', 'categories_with_requests', 'talent_per_cat_per_member']
#
# |Metric|Value|
# |-----|-----|
# |**Training R2**|0.63503|
# |**Testing R2**|-4.86918|
# |**Explained variance**|-4.68300|
# |**Mean absolute error (MAE)**|1.09681|
# |**Mean squared error (MSE)**|9.13827|
# |**Root mean squared error (RMSE)**|3.02296|
# |**Median absolute error (MedAE)**|0.31153|
# |**Mean distribution of residuals**|-0.53840|
#
#
# <table><tr><td><img src="../images/dist_190303_163408.png"></td><td><img src="../images/prob_190303_163408.png"></td></tr></table>
#
#
# ---

# %% [markdown]
# ### Model ID: 190303_163247 - ALL timebanks
# #### Selected model
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)
#
# #### Features
# ['const', 'sponsor', 'phone', 'facebook', 'twitter', 'mission_word_count', 'mission_sentiment', 'notes_sentiment', 'hours_per_exchange', 'avg_offers', 'avg_requests', 'offer_request_ratio', 'members_starting', 'members_daily_new', 'facebook_likes', 'facebook_followers', 'twitter_tweets', 'twitter_following', 'twitter_followers', 'categories_total', 'categories_parent', 'categories_with_offers', 'categories_with_requests', 'talent_per_cat_per_member']
#
# |Metric|Value|
# |-----|-----|
# |**Training R2**|0.63402|
# |**Testing R2**|-4.80771|
# |**Explained variance**|-4.62801|
# |**Mean absolute error (MAE)**|1.11210|
# |**Mean squared error (MSE)**|9.04256|
# |**Root mean squared error (RMSE)**|3.00708|
# |**Median absolute error (MedAE)**|0.31744|
# |**Mean distribution of residuals**|-0.52896|
#
#
# <table><tr><td><img src="../images/dist_190303_163247.png"></td><td><img src="../images/prob_190303_163247.png"></td></tr></table>
#
#
# ---

# %% [markdown]
# ### Model ID: 190303_163146 - ALL timebanks
# #### Selected model
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)
#
# #### Features
# ['const', 'sponsor', 'phone', 'url_2', 'facebook', 'twitter', 'mission_word_count', 'mission_sentiment', 'notes_sentiment', 'hours_per_exchange', 'avg_offers', 'avg_requests', 'offer_request_ratio', 'members_starting', 'members_daily_new', 'facebook_likes', 'facebook_followers', 'twitter_tweets', 'twitter_following', 'twitter_followers', 'categories_total', 'categories_parent', 'categories_with_offers', 'categories_with_requests', 'talent_per_cat_per_member']
#
# |Metric|Value|
# |-----|-----|
# |**Training R2**|0.63569|
# |**Testing R2**|-4.55788|
# |**Explained variance**|-4.37448|
# |**Mean absolute error (MAE)**|1.09131|
# |**Mean squared error (MSE)**|8.65358|
# |**Root mean squared error (RMSE)**|2.94170|
# |**Median absolute error (MedAE)**|0.27993|
# |**Mean distribution of residuals**|-0.53438|
#
#
# <table><tr><td><img src="../images/dist_190303_163146.png"></td><td><img src="../images/prob_190303_163146.png"></td></tr></table>
#
#
# ---

# %% [markdown]
# ### Model ID: 190303_163030 - ALL timebanks
# #### Selected model
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)
#
# #### Features
# ['const', 'sponsor', 'phone', 'url_2', 'facebook', 'twitter', 'mission_word_count', 'mission_sentiment', 'notes_word_count', 'hours_per_exchange', 'avg_offers', 'avg_requests', 'offer_request_ratio', 'members_starting', 'members_daily_new', 'facebook_likes', 'facebook_followers', 'twitter_tweets', 'twitter_following', 'twitter_followers', 'categories_total', 'categories_parent', 'categories_with_offers', 'categories_with_requests', 'talent_per_cat_per_member']
#
# |Metric|Value|
# |-----|-----|
# |**Training R2**|0.64450|
# |**Testing R2**|-4.96646|
# |**Explained variance**|-4.75100|
# |**Mean absolute error (MAE)**|1.14142|
# |**Mean squared error (MSE)**|9.28973|
# |**Root mean squared error (RMSE)**|3.04791|
# |**Median absolute error (MedAE)**|0.28579|
# |**Mean distribution of residuals**|-0.57920|
#
#
# <table><tr><td><img src="../images/dist_190303_163030.png"></td><td><img src="../images/prob_190303_163030.png"></td></tr></table>
#
#
# ---

# %% [markdown]
# ### Model ID: 190303_162839 - ALL timebanks
# #### Selected model
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)
#
# #### Features
# ['const', 'sponsor', 'phone', 'url_2', 'facebook', 'twitter', 'mission_word_count', 'mission_sentiment', 'notes_word_count', 'notes_sentiment', 'hours_per_exchange', 'avg_offers', 'avg_requests', 'offer_request_ratio', 'members_starting', 'members_daily_new', 'facebook_likes', 'facebook_followers', 'twitter_tweets', 'twitter_following', 'twitter_followers', 'categories_total', 'categories_parent', 'categories_with_offers', 'categories_with_requests', 'talent_per_cat_per_member']
#
# |Metric|Value|
# |-----|-----|
# |**Training R2**|0.64452|
# |**Testing R2**|-4.88866|
# |**Explained variance**|-4.67444|
# |**Mean absolute error (MAE)**|1.14016|
# |**Mean squared error (MSE)**|9.16859|
# |**Root mean squared error (RMSE)**|3.02797|
# |**Median absolute error (MedAE)**|0.28649|
# |**Mean distribution of residuals**|-0.57753|
#
#
# <table><tr><td><img src="../images/dist_190303_162839.png"></td><td><img src="../images/prob_190303_162839.png"></td></tr></table>
#
#
# ---
