# %% [markdown]
# # 06a. Timebanks: Modeling Results (1/24/19 - 2/7/19)
# > Author: [Dawn Graham](https://dawngraham.github.io/)
#
# Models created with: `combined_2019-01-24_2019-02-07.csv`
#
# Summaries of models included below:
# - Best model for ALL timebanks
# - Best model for ACTIVE timebanks
# - Decision tree for ALL timebanks
# - Lasso for ALL timebanks
# - Linear regression models for ACTIVE timebanks
# - Linear regression models for ALL timebanks
#
# For linear regression models, I used backward feature selection. I started with all features and removed one at a time, using RMSE as metric to judge if the model improved with removal. The models are ordered with the most recent closer to the top of the notebook.
#
# ---

# %% [markdown]
# ## Best model for ALL timebanks

# %% [markdown]
# ### Model ID: 190209_134253 - ALL timebanks
# #### Selected model
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)
#
# #### Features
# ['const', 'phone', 'facebook', 'mission_sentiment', 'notes_word_count', 'hours_per_exchange', 'avg_offers', 'avg_requests', 'offer_request_ratio', 'categories_with_requests']
#
# 54% of the variability in the data are explained by the model, relative to a model with no predictors.
#
# |Metric|Value|
# |-----|-----|
# |**Training R2**|0.40372|
# |**Testing R2**|0.54286|
# |**Explained variance**|0.55832|
# |**Mean absolute error (MAE)**|0.54460|
# |**Mean squared error (MSE)**|0.73381|
# |**Root mean squared error (RMSE)**|0.85663|
# |**Median absolute error (MedAE)**|0.28432|
# |**Mean distribution of residuals**|-0.15751|
#
# | Feature	|Coef|
# | - | - |
# |avg_requests|44.811131|
# |hours_per_exchange|0.684775|
# |phone|0.360892|
# |offer_request_ratio|0.245336|
# |categories_with_requests|0.078473|
# |const|0.000000|
# |mission_sentiment|-0.017525|
# |facebook|-0.178220|
# |notes_word_count|-0.254249|
# |avg_offers|-44.827840|
#
# For every increase by 1 in average number of requests, the model predicts daily average exchanges to increase by 45.
#
# <table><tr><td><img src="../images/dist_190209_134253.png"></td><td><img src="../images/prob_190209_134253.png"></td></tr></table>
#
#
# ---

# %% [markdown]
# ## Best model for ACTIVE timebanks

# %% [markdown]
# ### Model ID: 190209_141924 - ACTIVE timebanks
# #### Selected model
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)
#
# #### Features
# ['const', 'sponsor', 'facebook', 'twitter', 'mission_word_count', 'notes_word_count', 'avg_offers', 'avg_requests', 'facebook_likes', 'facebook_followers']
#
# 40% of the variability in the data are explained by the model, relative to a model with no predictors.
#
# |Metric|Value|
# |-----|-----|
# |**Training R2**|0.28747|
# |**Testing R2**|0.39810|
# |**Explained variance**|0.56423|
# |**Mean absolute error (MAE)**|1.32356|
# |**Mean squared error (MSE)**|2.12480|
# |**Root mean squared error (RMSE)**|1.45767|
# |**Median absolute error (MedAE)**|1.24450|
# |**Mean distribution of residuals**|-0.76582|
#
# |Feature|Coef|
# | - | - |
# |facebook_followers|12.972546|
# |avg_requests|3.694976|
# |sponsor|0.324385|
# |const|0.000000|
# |mission_word_count|-0.112127|
# |facebook|-0.149091|
# |notes_word_count|-0.218467|
# |twitter|-0.312996|
# |avg_offers|-2.647074|
# |facebook_likes|-13.586696|
#
# For every Facebook Follower, the model predicts daily average exchanges to increase by 13.
#
# <table><tr><td><img src="../images/dist_190209_141924.png"></td><td><img src="../images/prob_190209_141924.png"></td></tr></table>
#
#
# ---

# %% [markdown]
# ---
#
# ## Decision Tree

# %% [markdown]
# ### Model ID: 190209_180636 - ALL timebanks
# #### Selected model
# DecisionTreeRegressor(criterion='mse', max_depth=4, max_features='auto',
#            max_leaf_nodes=15, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            presort=False, random_state=42, splitter='random')
#
# #### Features
# ['const', 'phone', 'facebook', 'mission_sentiment', 'notes_word_count', 'hours_per_exchange', 'avg_offers', 'avg_requests', 'offer_request_ratio', 'categories_with_requests']
#
# |Metric|Value|
# |-----|-----|
# |**Training R2**|0.86770|
# |**Testing R2**|0.28028|
# |**Explained variance**|0.29172|
# |**Mean absolute error (MAE)**|0.52129|
# |**Mean squared error (MSE)**|1.15532|
# |**Root mean squared error (RMSE)**|1.07486|
# |**Median absolute error (MedAE)**|0.20301|
# |**Mean distribution of residuals**|0.13554|
#
#
# <table><tr><td><img src="../images/dist_190209_180636.png"></td><td><img src="../images/prob_190209_180636.png"></td></tr></table>
#
# <img src="../images/tree_190209_180636.png">
#
#
# ---

# %% [markdown]
# ---
#
# ## Lasso

# %% [markdown]
# ### Model ID: 190209_164337 - ALL timebanks
# #### Selected model
# LassoCV(alphas=None, copy_X=True, cv='warn', eps=0.001, fit_intercept=True,
#     max_iter=86, n_alphas=5, n_jobs=None, normalize=False, positive=False,
#     precompute='auto', random_state=42, selection='cyclic', tol=0.0001,
#     verbose=False)
#
# #### Features
# ['const', 'phone', 'facebook', 'mission_sentiment', 'notes_word_count', 'hours_per_exchange', 'avg_offers', 'avg_requests', 'offer_request_ratio', 'categories_with_requests']
#
# |Metric|Value|
# |-----|-----|
# |**Training R2**|0.30490|
# |**Testing R2**|0.37185|
# |**Explained variance**|0.37700|
# |**Mean absolute error (MAE)**|0.58829|
# |**Mean squared error (MSE)**|1.00832|
# |**Root mean squared error (RMSE)**|1.00415|
# |**Median absolute error (MedAE)**|0.15557|
# |**Mean distribution of residuals**|-0.09089|
#
#
# <table><tr><td><img src="../images/dist_190209_164337.png"></td><td><img src="../images/prob_190209_164337.png"></td></tr></table>
#
#
# ---

# %% [markdown]
# ---
#
# ## Linear Regression for ACTIVE Timebanks

# %% [markdown]
# ### Model ID: 190209_142019 - ACTIVE timebanks
# #### Selected model
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)
#
# #### Features
# ['const', 'sponsor', 'facebook', 'twitter', 'mission_word_count', 'notes_word_count', 'avg_offers', 'facebook_likes', 'facebook_followers']
#
# |Metric|Value|
# |-----|-----|
# |**Training R2**|0.12574|
# |**Testing R2**|0.36727|
# |**Explained variance**|0.45390|
# |**Mean absolute error (MAE)**|1.31219|
# |**Mean squared error (MSE)**|2.23364|
# |**Root mean squared error (RMSE)**|1.49454|
# |**Median absolute error (MedAE)**|1.09765|
# |**Mean distribution of residuals**|-0.55302|
#
#
# <table><tr><td><img src="../images/dist_190209_142019.png"></td><td><img src="../images/prob_190209_142019.png"></td></tr></table>
#
#
# ---

# %% [markdown]
# ### Model ID: 190209_141924 - ACTIVE timebanks
# #### Selected model
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)
#
# #### Features
# ['const', 'sponsor', 'facebook', 'twitter', 'mission_word_count', 'notes_word_count', 'avg_offers', 'avg_requests', 'facebook_likes', 'facebook_followers']
#
# |Metric|Value|
# |-----|-----|
# |**Training R2**|0.28747|
# |**Testing R2**|0.39810|
# |**Explained variance**|0.56423|
# |**Mean absolute error (MAE)**|1.32356|
# |**Mean squared error (MSE)**|2.12480|
# |**Root mean squared error (RMSE)**|1.45767|
# |**Median absolute error (MedAE)**|1.24450|
# |**Mean distribution of residuals**|-0.76582|
#
#
# <table><tr><td><img src="../images/dist_190209_141924.png"></td><td><img src="../images/prob_190209_141924.png"></td></tr></table>
#
#
# ---

# %% [markdown]
# ### Model ID: 190209_141837 - ACTIVE timebanks
# #### Selected model
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)
#
# #### Features
# ['const', 'sponsor', 'facebook', 'twitter', 'mission_word_count', 'notes_word_count', 'avg_requests', 'members_starting', 'facebook_likes', 'facebook_followers']
#
# |Metric|Value|
# |-----|-----|
# |**Training R2**|0.40687|
# |**Testing R2**|0.16998|
# |**Explained variance**|0.28450|
# |**Mean absolute error (MAE)**|1.28274|
# |**Mean squared error (MSE)**|2.93011|
# |**Root mean squared error (RMSE)**|1.71176|
# |**Median absolute error (MedAE)**|1.05227|
# |**Mean distribution of residuals**|-0.63584|
#
#
# <table><tr><td><img src="../images/dist_190209_141837.png"></td><td><img src="../images/prob_190209_141837.png"></td></tr></table>
#
#
# ---

# %% [markdown]
# ### Model ID: 190209_141758 - ACTIVE timebanks
# #### Selected model
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)
#
# #### Features
# ['const', 'sponsor', 'facebook', 'twitter', 'mission_word_count', 'notes_word_count', 'avg_offers', 'avg_requests', 'members_starting', 'facebook_likes', 'facebook_followers']
#
#
# |Metric|Value|
# |-----|-----|
# |**Training R2**|0.43990|
# |**Testing R2**|0.35835|
# |**Explained variance**|0.46979|
# |**Mean absolute error (MAE)**|1.16787|
# |**Mean squared error (MSE)**|2.26512|
# |**Root mean squared error (RMSE)**|1.50503|
# |**Median absolute error (MedAE)**|0.88306|
# |**Mean distribution of residuals**|-0.62721|
#
#
# <table><tr><td><img src="../images/dist_190209_141758.png"></td><td><img src="../images/prob_190209_141758.png"></td></tr></table>
#
#
# ---

# %% [markdown]
# ### Model ID: 190209_141703 - ACTIVE timebanks
# #### Selected model
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)
#
# #### Features
# ['const', 'sponsor', 'facebook', 'twitter', 'mission_word_count', 'notes_word_count', 'avg_offers', 'avg_requests', 'members_starting', 'facebook_likes', 'facebook_followers', 'categories_with_requests']
#
# |Metric|Value|
# |-----|-----|
# |**Training R2**|0.46691|
# |**Testing R2**|0.27174|
# |**Explained variance**|0.41561|
# |**Mean absolute error (MAE)**|1.34545|
# |**Mean squared error (MSE)**|2.57086|
# |**Root mean squared error (RMSE)**|1.60339|
# |**Median absolute error (MedAE)**|1.29523|
# |**Mean distribution of residuals**|-0.71266|
#
#
# <table><tr><td><img src="../images/dist_190209_141703.png"></td><td><img src="../images/prob_190209_141703.png"></td></tr></table>
#
#
# ---

# %% [markdown]
# ### Model ID: 190209_141623 - ACTIVE timebanks
# #### Selected model
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)
#
# #### Features
# ['const', 'sponsor', 'facebook', 'twitter', 'mission_word_count', 'notes_word_count', 'avg_offers', 'avg_requests', 'members_starting', 'facebook_likes', 'facebook_followers', 'categories_total', 'categories_with_requests']
#
# |Metric|Value|
# |-----|-----|
# |**Training R2**|0.51681|
# |**Testing R2**|0.14061|
# |**Explained variance**|0.23458|
# |**Mean absolute error (MAE)**|1.54376|
# |**Mean squared error (MSE)**|3.03376|
# |**Root mean squared error (RMSE)**|1.74177|
# |**Median absolute error (MedAE)**|1.77908|
# |**Mean distribution of residuals**|-0.57596|
#
#
# <table><tr><td><img src="../images/dist_190209_141623.png"></td><td><img src="../images/prob_190209_141623.png"></td></tr></table>
#
#
# ---

# %% [markdown]
# ### Model ID: 190209_141352 - ACTIVE timebanks
# #### Selected model
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)
#
# #### Features
# ['const', 'sponsor', 'facebook', 'twitter', 'mission_word_count', 'notes_word_count', 'hours_per_exchange', 'avg_offers', 'avg_requests', 'members_starting', 'facebook_likes', 'facebook_followers', 'categories_total', 'categories_with_requests']
#
# |Metric|Value|
# |-----|-----|
# |**Training R2**|0.58506|
# |**Testing R2**|-0.06333|
# |**Explained variance**|0.02377|
# |**Mean absolute error (MAE)**|1.73831|
# |**Mean squared error (MSE)**|3.75371|
# |**Root mean squared error (RMSE)**|1.93745|
# |**Median absolute error (MedAE)**|1.81047|
# |**Mean distribution of residuals**|-0.55451|
#
#
# <table><tr><td><img src="../images/dist_190209_141352.png"></td><td><img src="../images/prob_190209_141352.png"></td></tr></table>
#
#
# ---

# %% [markdown]
# ### Model ID: 190209_141315 - ACTIVE timebanks
# #### Selected model
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)
#
# #### Features
# ['const', 'sponsor', 'phone', 'twitter', 'mission_word_count', 'notes_word_count', 'hours_per_exchange', 'avg_offers', 'avg_requests', 'members_starting', 'facebook_likes', 'facebook_followers', 'categories_total', 'categories_with_requests']
#
# |Metric|Value|
# |-----|-----|
# |**Training R2**|0.58495|
# |**Testing R2**|-0.07463|
# |**Explained variance**|0.01117|
# |**Mean absolute error (MAE)**|1.74731|
# |**Mean squared error (MSE)**|3.79362|
# |**Root mean squared error (RMSE)**|1.94772|
# |**Median absolute error (MedAE)**|1.83756|
# |**Mean distribution of residuals**|-0.55038|
#
#
# <table><tr><td><img src="../images/dist_190209_141315.png"></td><td><img src="../images/prob_190209_141315.png"></td></tr></table>
#
#
# ---

# %% [markdown]
# ### Model ID: 190209_141201 - ACTIVE timebanks
# #### Selected model
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)
#
# #### Features
# ['const', 'sponsor', 'phone', 'facebook', 'twitter', 'mission_word_count', 'notes_word_count', 'hours_per_exchange', 'avg_offers', 'avg_requests', 'members_starting', 'facebook_likes', 'facebook_followers', 'categories_total', 'categories_with_requests']
#
# |Metric|Value|
# |-----|-----|
# |**Training R2**|0.58506|
# |**Testing R2**|-0.06333|
# |**Explained variance**|0.02377|
# |**Mean absolute error (MAE)**|1.73831|
# |**Mean squared error (MSE)**|3.75371|
# |**Root mean squared error (RMSE)**|1.93745|
# |**Median absolute error (MedAE)**|1.81047|
# |**Mean distribution of residuals**|-0.55451|
#
#
# <table><tr><td><img src="../images/dist_190209_141201.png"></td><td><img src="../images/prob_190209_141201.png"></td></tr></table>
#
#
# ---

# %% [markdown]
# ### Model ID: 190209_141117 - ACTIVE timebanks
# #### Selected model
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)
#
# #### Features
# ['const', 'sponsor', 'phone', 'facebook', 'twitter', 'mission_word_count', 'notes_word_count', 'hours_per_exchange', 'avg_offers', 'avg_requests', 'members_starting', 'facebook_likes', 'facebook_followers', 'categories_total', 'categories_parent', 'categories_with_requests']
#
# |Metric|Value|
# |-----|-----|
# |**Training R2**|0.59355|
# |**Testing R2**|-0.10890|
# |**Explained variance**|-0.03448|
# |**Mean absolute error (MAE)**|1.77107|
# |**Mean squared error (MSE)**|3.91457|
# |**Root mean squared error (RMSE)**|1.97853|
# |**Median absolute error (MedAE)**|1.85595|
# |**Mean distribution of residuals**|-0.51256|
#
#
# <table><tr><td><img src="../images/dist_190209_141117.png"></td><td><img src="../images/prob_190209_141117.png"></td></tr></table>
#
#
# ---

# %% [markdown]
# ### Model ID: 190209_141030 - ACTIVE timebanks
# #### Selected model
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)
#
# #### Features
# ['const', 'sponsor', 'phone', 'facebook', 'twitter', 'mission_word_count', 'notes_word_count', 'hours_per_exchange', 'avg_offers', 'avg_requests', 'members_starting', 'facebook_likes', 'facebook_followers', 'twitter_following', 'categories_total', 'categories_parent', 'categories_with_requests']
#
# |Metric|Value|
# |-----|-----|
# |**Training R2**|0.59850|
# |**Testing R2**|-0.13754|
# |**Explained variance**|-0.07170|
# |**Mean absolute error (MAE)**|1.77920|
# |**Mean squared error (MSE)**|4.01570|
# |**Root mean squared error (RMSE)**|2.00392|
# |**Median absolute error (MedAE)**|1.78767|
# |**Mean distribution of residuals**|-0.48212|
#
#
# <table><tr><td><img src="../images/dist_190209_141030.png"></td><td><img src="../images/prob_190209_141030.png"></td></tr></table>
#
#
# ---

# %% [markdown]
# ### Model ID: 190209_140948 - ACTIVE timebanks
# #### Selected model
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)
#
# #### Features
# ['const', 'sponsor', 'phone', 'facebook', 'twitter', 'mission_word_count', 'mission_sentiment', 'notes_word_count', 'hours_per_exchange', 'avg_offers', 'avg_requests', 'members_starting', 'facebook_likes', 'twitter_following', 'categories_total', 'categories_parent', 'categories_with_requests']
#
# |Metric|Value|
# |-----|-----|
# |**Training R2**|0.63346|
# |**Testing R2**|-0.72690|
# |**Explained variance**|-0.31748|
# |**Mean absolute error (MAE)**|2.17550|
# |**Mean squared error (MSE)**|6.09620|
# |**Root mean squared error (RMSE)**|2.46905|
# |**Median absolute error (MedAE)**|2.22435|
# |**Mean distribution of residuals**|-1.20221|
#
#
# <table><tr><td><img src="../images/dist_190209_140948.png"></td><td><img src="../images/prob_190209_140948.png"></td></tr></table>
#
#
# ---

# %% [markdown]
# ### Model ID: 190209_140907 - ACTIVE timebanks
# #### Selected model
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)
#
# #### Features
# ['const', 'sponsor', 'phone', 'facebook', 'twitter', 'mission_word_count', 'mission_sentiment', 'notes_word_count', 'hours_per_exchange', 'avg_offers', 'avg_requests', 'members_starting', 'facebook_followers', 'twitter_following', 'categories_total', 'categories_parent', 'categories_with_requests']
#
# |Metric|Value|
# |-----|-----|
# |**Training R2**|0.63175|
# |**Testing R2**|-0.74605|
# |**Explained variance**|-0.32892|
# |**Mean absolute error (MAE)**|2.19422|
# |**Mean squared error (MSE)**|6.16382|
# |**Root mean squared error (RMSE)**|2.48270|
# |**Median absolute error (MedAE)**|2.19363|
# |**Mean distribution of residuals**|-1.21348|
#
#
# <table><tr><td><img src="../images/dist_190209_140907.png"></td><td><img src="../images/prob_190209_140907.png"></td></tr></table>
#
#
# ---

# %% [markdown]
# ### Model ID: 190209_140824 - ACTIVE timebanks
# #### Selected model
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)
#
# #### Features
# ['const', 'sponsor', 'phone', 'facebook', 'twitter', 'mission_sentiment', 'notes_word_count', 'hours_per_exchange', 'avg_offers', 'avg_requests', 'members_starting', 'facebook_likes', 'facebook_followers', 'twitter_following', 'categories_total', 'categories_parent', 'categories_with_requests']
#
# |Metric|Value|
# |-----|-----|
# |**Training R2**|0.64112|
# |**Testing R2**|-0.59160|
# |**Explained variance**|-0.23035|
# |**Mean absolute error (MAE)**|2.03383|
# |**Mean squared error (MSE)**|5.61858|
# |**Root mean squared error (RMSE)**|2.37035|
# |**Median absolute error (MedAE)**|2.27387|
# |**Mean distribution of residuals**|-1.12928|
#
#
# <table><tr><td><img src="../images/dist_190209_140824.png"></td><td><img src="../images/prob_190209_140824.png"></td></tr></table>
#
#
# ---

# %% [markdown]
# ### Model ID: 190209_140716 - ACTIVE timebanks
# #### Selected model
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)
#
# #### Features
# ['const', 'sponsor', 'phone', 'facebook', 'twitter', 'mission_word_count', 'mission_sentiment', 'notes_word_count', 'hours_per_exchange', 'avg_offers', 'avg_requests', 'members_starting', 'facebook_likes', 'facebook_followers', 'twitter_following', 'categories_total', 'categories_parent', 'categories_with_requests']
#
# |Metric|Value|
# |-----|-----|
# |**Training R2**|0.64267|
# |**Testing R2**|-0.57295|
# |**Explained variance**|-0.25676|
# |**Mean absolute error (MAE)**|2.00328|
# |**Mean squared error (MSE)**|5.55275|
# |**Root mean squared error (RMSE)**|2.35643|
# |**Median absolute error (MedAE)**|2.22165|
# |**Mean distribution of residuals**|-1.05650|
#
#
# <table><tr><td><img src="../images/dist_190209_140716.png"></td><td><img src="../images/prob_190209_140716.png"></td></tr></table>
#
#
# ---

# %% [markdown]
# ### Model ID: 190209_140547 - ACTIVE timebanks
# #### Selected model
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)
#
# #### Features
# ['const', 'sponsor', 'phone', 'facebook', 'twitter', 'mission_word_count', 'mission_sentiment', 'notes_word_count', 'hours_per_exchange', 'avg_offers', 'avg_requests', 'members_starting', 'facebook_likes', 'facebook_followers', 'twitter_following', 'categories_total', 'categories_parent', 'categories_with_requests', 'talent_per_cat_per_member']
#
# |Metric|Value|
# |-----|-----|
# |**Training R2**|0.64494|
# |**Testing R2**|-0.76221|
# |**Explained variance**|-0.36670|
# |**Mean absolute error (MAE)**|2.08782|
# |**Mean squared error (MSE)**|6.22085|
# |**Root mean squared error (RMSE)**|2.49416|
# |**Median absolute error (MedAE)**|2.31994|
# |**Mean distribution of residuals**|-1.18161|
#
#
# <table><tr><td><img src="../images/dist_190209_140547.png"></td><td><img src="../images/prob_190209_140547.png"></td></tr></table>
#
#
# ---

# %% [markdown]
# ### Model ID: 190209_140502 - ACTIVE timebanks
# #### Selected model
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)
#
# #### Features
# ['const', 'sponsor', 'phone', 'facebook', 'twitter', 'mission_word_count', 'mission_sentiment', 'notes_word_count', 'hours_per_exchange', 'avg_offers', 'avg_requests', 'members_starting', 'facebook_likes', 'facebook_followers', 'twitter_tweets', 'twitter_following', 'categories_total', 'categories_parent', 'categories_with_requests', 'talent_per_cat_per_member']
#
# |Metric|Value|
# |-----|-----|
# |**Training R2**|0.64575|
# |**Testing R2**|-0.76338|
# |**Explained variance**|-0.35652|
# |**Mean absolute error (MAE)**|2.05499|
# |**Mean squared error (MSE)**|6.22499|
# |**Root mean squared error (RMSE)**|2.49499|
# |**Median absolute error (MedAE)**|2.26820|
# |**Mean distribution of residuals**|-1.19845|
#
#
# <table><tr><td><img src="../images/dist_190209_140502.png"></td><td><img src="../images/prob_190209_140502.png"></td></tr></table>
#
#
# ---

# %% [markdown]
# ### Model ID: 190209_140421 - ACTIVE timebanks
# #### Selected model
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)
#
# #### Features
# ['const', 'sponsor', 'phone', 'facebook', 'mission_word_count', 'mission_sentiment', 'notes_word_count', 'hours_per_exchange', 'avg_offers', 'avg_requests', 'members_starting', 'facebook_likes', 'facebook_followers', 'twitter_tweets', 'twitter_following', 'twitter_followers', 'categories_total', 'categories_parent', 'categories_with_requests', 'talent_per_cat_per_member']
#
# |Metric|Value|
# |-----|-----|
# |**Training R2**|0.63501|
# |**Testing R2**|-1.56358|
# |**Explained variance**|-0.63182|
# |**Mean absolute error (MAE)**|2.76135|
# |**Mean squared error (MSE)**|9.04981|
# |**Root mean squared error (RMSE)**|3.00829|
# |**Median absolute error (MedAE)**|2.97990|
# |**Mean distribution of residuals**|-1.81363|
#
#
# <table><tr><td><img src="../images/dist_190209_140421.png"></td><td><img src="../images/prob_190209_140421.png"></td></tr></table>
#
#
# ---

# %% [markdown]
# ### Model ID: 190209_140322 - ACTIVE timebanks
# #### Selected model
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)
#
# #### Features
# ['const', 'sponsor', 'phone', 'facebook', 'twitter', 'mission_word_count', 'mission_sentiment', 'notes_word_count', 'hours_per_exchange', 'avg_offers', 'avg_requests', 'members_starting', 'facebook_likes', 'facebook_followers', 'twitter_tweets', 'twitter_following', 'twitter_followers', 'categories_total', 'categories_parent', 'categories_with_requests', 'talent_per_cat_per_member']
#
# |Metric|Value|
# |-----|-----|
# |**Training R2**|0.65395|
# |**Testing R2**|-1.18348|
# |**Explained variance**|-0.44079|
# |**Mean absolute error (MAE)**|2.47369|
# |**Mean squared error (MSE)**|7.70800|
# |**Root mean squared error (RMSE)**|2.77633|
# |**Median absolute error (MedAE)**|2.19072|
# |**Mean distribution of residuals**|-1.61920|
#
#
# <table><tr><td><img src="../images/dist_190209_140322.png"></td><td><img src="../images/prob_190209_140322.png"></td></tr></table>
#
#
# ---

# %% [markdown]
# ### Model ID: 190209_140234 - ACTIVE timebanks
# #### Selected model
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)
#
# #### Features
# ['const', 'phone', 'facebook', 'twitter', 'mission_word_count', 'mission_sentiment', 'notes_word_count', 'hours_per_exchange', 'avg_offers', 'avg_requests', 'members_starting', 'facebook_likes', 'facebook_followers', 'twitter_tweets', 'twitter_following', 'twitter_followers', 'categories_total', 'categories_parent', 'categories_with_offers', 'categories_with_requests', 'talent_per_cat_per_member']
#
# |Metric|Value|
# |-----|-----|
# |**Training R2**|0.65914|
# |**Testing R2**|-1.62116|
# |**Explained variance**|-0.50652|
# |**Mean absolute error (MAE)**|2.71821|
# |**Mean squared error (MSE)**|9.25310|
# |**Root mean squared error (RMSE)**|3.04189|
# |**Median absolute error (MedAE)**|2.94639|
# |**Mean distribution of residuals**|-1.98365|
#
#
# <table><tr><td><img src="../images/dist_190209_140234.png"></td><td><img src="../images/prob_190209_140234.png"></td></tr></table>
#
#
# ---

# %% [markdown]
# ### Model ID: 190209_140202 - ACTIVE timebanks
# #### Selected model
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)
#
# #### Features
# ['const', 'sponsor', 'phone', 'facebook', 'twitter', 'mission_word_count', 'mission_sentiment', 'notes_word_count', 'hours_per_exchange', 'avg_offers', 'avg_requests', 'members_starting', 'facebook_likes', 'facebook_followers', 'twitter_tweets', 'twitter_following', 'twitter_followers', 'categories_total', 'categories_parent', 'categories_with_offers', 'categories_with_requests', 'talent_per_cat_per_member']
#
# |Metric|Value|
# |-----|-----|
# |**Training R2**|0.66330|
# |**Testing R2**|-1.35129|
# |**Explained variance**|-0.36469|
# |**Mean absolute error (MAE)**|2.58626|
# |**Mean squared error (MSE)**|8.30041|
# |**Root mean squared error (RMSE)**|2.88104|
# |**Median absolute error (MedAE)**|2.96113|
# |**Mean distribution of residuals**|-1.86624|
#
#
# <table><tr><td><img src="../images/dist_190209_140202.png"></td><td><img src="../images/prob_190209_140202.png"></td></tr></table>
#
#
# ---

# %% [markdown]
# ### Model ID: 190209_140109 - ACTIVE timebanks
# #### Selected model
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)
#
# #### Features
# ['const', 'sponsor', 'phone', 'url_2', 'facebook', 'twitter', 'mission_word_count', 'mission_sentiment', 'hours_per_exchange', 'avg_offers', 'avg_requests', 'members_starting', 'facebook_likes', 'facebook_followers', 'twitter_tweets', 'twitter_following', 'twitter_followers', 'categories_total', 'categories_parent', 'categories_with_offers', 'categories_with_requests', 'talent_per_cat_per_member']
#
# |Metric|Value|
# |-----|-----|
# |**Training R2**|0.63714|
# |**Testing R2**|-2.42395|
# |**Explained variance**|-0.69337|
# |**Mean absolute error (MAE)**|3.04165|
# |**Mean squared error (MSE)**|12.08706|
# |**Root mean squared error (RMSE)**|3.47665|
# |**Median absolute error (MedAE)**|2.70873|
# |**Mean distribution of residuals**|-2.47168|
#
#
# <table><tr><td><img src="../images/dist_190209_140109.png"></td><td><img src="../images/prob_190209_140109.png"></td></tr></table>
#
#
# ---

# %% [markdown]
# ### Model ID: 190209_140014 - ACTIVE timebanks
# #### Selected model
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)
#
# #### Features
# ['const', 'sponsor', 'phone', 'url_2', 'facebook', 'twitter', 'mission_word_count', 'mission_sentiment', 'notes_word_count', 'hours_per_exchange', 'avg_offers', 'avg_requests', 'members_starting', 'facebook_likes', 'facebook_followers', 'twitter_tweets', 'twitter_following', 'twitter_followers', 'categories_total', 'categories_parent', 'categories_with_offers', 'categories_with_requests', 'talent_per_cat_per_member']
#
# |Metric|Value|
# |-----|-----|
# |**Training R2**|0.67573|
# |**Testing R2**|-1.96289|
# |**Explained variance**|-0.57221|
# |**Mean absolute error (MAE)**|2.93808|
# |**Mean squared error (MSE)**|10.45945|
# |**Root mean squared error (RMSE)**|3.23411|
# |**Median absolute error (MedAE)**|2.96714|
# |**Mean distribution of residuals**|-2.21570|
#
#
# <table><tr><td><img src="../images/dist_190209_140014.png"></td><td><img src="../images/prob_190209_140014.png"></td></tr></table>
#
#
# ---

# %% [markdown]
# ### Model ID: 190209_135846 - ACTIVE timebanks
# #### Selected model
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)
#
# #### Features
# ['const', 'sponsor', 'phone', 'url_2', 'facebook', 'twitter', 'mission_word_count', 'mission_sentiment', 'notes_word_count', 'notes_sentiment', 'hours_per_exchange', 'avg_offers', 'avg_requests', 'members_starting', 'facebook_likes', 'facebook_followers', 'twitter_tweets', 'twitter_following', 'twitter_followers', 'categories_total', 'categories_parent', 'categories_with_offers', 'categories_with_requests', 'talent_per_cat_per_member']
#
# |Metric|Value|
# |-----|-----|
# |**Training R2**|0.69573|
# |**Testing R2**|-2.24873|
# |**Explained variance**|-0.56940|
# |**Mean absolute error (MAE)**|2.95252|
# |**Mean squared error (MSE)**|11.46851|
# |**Root mean squared error (RMSE)**|3.38652|
# |**Median absolute error (MedAE)**|3.25250|
# |**Mean distribution of residuals**|-2.43481|
#
#
# <table><tr><td><img src="../images/dist_190209_135846.png"></td><td><img src="../images/prob_190209_135846.png"></td></tr></table>
#
#
# ---

# %% [markdown]
# ### Model ID: 190209_135747 - ACTIVE timebanks
# #### Selected model
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)
#
# #### Features
# ['const', 'sponsor', 'phone', 'url_2', 'facebook', 'twitter', 'mission_word_count', 'mission_sentiment', 'notes_word_count', 'notes_sentiment', 'hours_per_exchange', 'avg_offers', 'avg_requests', 'offer_request_ratio', 'members_starting', 'facebook_likes', 'facebook_followers', 'twitter_tweets', 'twitter_following', 'twitter_followers', 'categories_total', 'categories_parent', 'categories_with_offers', 'categories_with_requests', 'talent_per_cat_per_member']
#
# |Metric|Value|
# |-----|-----|
# |**Training R2**|0.71734|
# |**Testing R2**|-2.31839|
# |**Explained variance**|-0.67379|
# |**Mean absolute error (MAE)**|3.09107|
# |**Mean squared error (MSE)**|11.71443|
# |**Root mean squared error (RMSE)**|3.42264|
# |**Median absolute error (MedAE)**|2.74665|
# |**Mean distribution of residuals**|-2.40950|
#
#
# <table><tr><td><img src="../images/dist_190209_135747.png"></td><td><img src="../images/prob_190209_135747.png"></td></tr></table>
#
#
# ---

# %% [markdown]
# ### Model ID: 190209_135642 - ACTIVE timebanks
# #### Selected model
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)
#
# #### Features
# ['const', 'sponsor', 'phone', 'url_2', 'facebook', 'twitter', 'mission_word_count', 'mission_sentiment', 'notes_word_count', 'notes_sentiment', 'hours_per_exchange', 'avg_offers', 'avg_requests', 'offer_request_ratio', 'members_starting', 'members_daily_new', 'facebook_likes', 'facebook_followers', 'twitter_tweets', 'twitter_following', 'twitter_followers', 'categories_total', 'categories_parent', 'categories_with_offers', 'categories_with_requests', 'talent_per_cat_per_member']
#
# |Metric|Value|
# |-----|-----|
# |**Training R2**|-3.90124|
# |**Testing R2**|-383.31015|
# |**Explained variance**|-369.68818|
# |**Mean absolute error (MAE)**|15.99554|
# |**Mean squared error (MSE)**|1356.67311|
# |**Root mean squared error (RMSE)**|36.83304|
# |**Median absolute error (MedAE)**|6.54018|
# |**Mean distribution of residuals**|6.93452|
#
#
# <table><tr><td><img src="../images/dist_190209_135642.png"></td><td><img src="../images/prob_190209_135642.png"></td></tr></table>
#
#
# ---

# %% [markdown]
# ## Linear Regression for ALL Timebanks

# %% [markdown]
# ### Model ID: 190209_134526 - ALL timebanks
# #### Selected model
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)
#
# #### Features
# ['const', 'phone', 'facebook', 'mission_sentiment', 'notes_word_count', 'avg_offers', 'avg_requests', 'offer_request_ratio', 'categories_with_requests']
#
# |Metric|Value|
# |-----|-----|
# |**Training R2**|0.30415|
# |**Testing R2**|0.53073|
# |**Explained variance**|0.54144|
# |**Mean absolute error (MAE)**|0.64386|
# |**Mean squared error (MSE)**|0.75328|
# |**Root mean squared error (RMSE)**|0.86791|
# |**Median absolute error (MedAE)**|0.56414|
# |**Mean distribution of residuals**|-0.13110|
#
#
# <table><tr><td><img src="../images/dist_190209_134526.png"></td><td><img src="../images/prob_190209_134526.png"></td></tr></table>
#
#
# ---

# %% [markdown]
# ### Model ID: 190209_134422 - ALL timebanks
# #### Selected model
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)
#
# #### Features
# ['const', 'phone', 'facebook', 'mission_sentiment', 'notes_word_count', 'hours_per_exchange', 'avg_offers', 'avg_requests', 'offer_request_ratio']
#
# |Metric|Value|
# |-----|-----|
# |**Training R2**|0.40252|
# |**Testing R2**|0.53733|
# |**Explained variance**|0.55301|
# |**Mean absolute error (MAE)**|0.55019|
# |**Mean squared error (MSE)**|0.74268|
# |**Root mean squared error (RMSE)**|0.86179|
# |**Median absolute error (MedAE)**|0.29362|
# |**Mean distribution of residuals**|-0.15866|
#
#
# <table><tr><td><img src="../images/dist_190209_134422.png"></td><td><img src="../images/prob_190209_134422.png"></td></tr></table>
#
#
# ---

# %% [markdown]
# ### Model ID: 190209_134253 - ALL timebanks
# #### Selected model
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)
#
# #### Features
# ['const', 'phone', 'facebook', 'mission_sentiment', 'notes_word_count', 'hours_per_exchange', 'avg_offers', 'avg_requests', 'offer_request_ratio', 'categories_with_requests']
#
# |Metric|Value|
# |-----|-----|
# |**Training R2**|0.40372|
# |**Testing R2**|0.54286|
# |**Explained variance**|0.55832|
# |**Mean absolute error (MAE)**|0.54460|
# |**Mean squared error (MSE)**|0.73381|
# |**Root mean squared error (RMSE)**|0.85663|
# |**Median absolute error (MedAE)**|0.28432|
# |**Mean distribution of residuals**|-0.15751|
#
#
# <table><tr><td><img src="../images/dist_190209_134253.png"></td><td><img src="../images/prob_190209_134253.png"></td></tr></table>
#
#
# ---

# %% [markdown]
# ### Model ID: 190209_134143 - ALL timebanks
# #### Selected model
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)
#
# #### Features
# ['const', 'phone', 'facebook', 'mission_sentiment', 'notes_word_count', 'hours_per_exchange', 'avg_offers', 'avg_requests', 'offer_request_ratio', 'members_starting', 'categories_with_requests']
#
# |Metric|Value|
# |-----|-----|
# |**Training R2**|0.45507|
# |**Testing R2**|0.41035|
# |**Explained variance**|0.44801|
# |**Mean absolute error (MAE)**|0.59083|
# |**Mean squared error (MSE)**|0.94651|
# |**Root mean squared error (RMSE)**|0.97289|
# |**Median absolute error (MedAE)**|0.21500|
# |**Mean distribution of residuals**|-0.24587|
#
#
# <table><tr><td><img src="../images/dist_190209_134143.png"></td><td><img src="../images/prob_190209_134143.png"></td></tr></table>
#
#
# ---

# %% [markdown]
# ### Model ID: 190209_134034 - ALL timebanks
# #### Selected model
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)
#
# #### Features
# ['const', 'phone', 'facebook', 'mission_sentiment', 'notes_word_count', 'hours_per_exchange', 'avg_offers', 'avg_requests', 'offer_request_ratio', 'members_starting', 'categories_total', 'categories_with_requests']
#
# |Metric|Value|
# |-----|-----|
# |**Training R2**|0.46024|
# |**Testing R2**|0.40198|
# |**Explained variance**|0.44413|
# |**Mean absolute error (MAE)**|0.57822|
# |**Mean squared error (MSE)**|0.95996|
# |**Root mean squared error (RMSE)**|0.97977|
# |**Median absolute error (MedAE)**|0.21657|
# |**Mean distribution of residuals**|-0.26012|
#
#
# <table><tr><td><img src="../images/dist_190209_134034.png"></td><td><img src="../images/prob_190209_134034.png"></td></tr></table>
#
#
# ---

# %% [markdown]
# ### Model ID: 190209_133947 - ALL timebanks
# #### Selected model
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)
#
# #### Features
# ['const', 'phone', 'mission_sentiment', 'notes_word_count', 'hours_per_exchange', 'avg_offers', 'avg_requests', 'offer_request_ratio', 'members_starting', 'categories_total', 'categories_with_offers', 'categories_with_requests']
#
# |Metric|Value|
# |-----|-----|
# |**Training R2**|0.46033|
# |**Testing R2**|0.36574|
# |**Explained variance**|0.40927|
# |**Mean absolute error (MAE)**|0.61925|
# |**Mean squared error (MSE)**|1.01813|
# |**Root mean squared error (RMSE)**|1.00902|
# |**Median absolute error (MedAE)**|0.30358|
# |**Mean distribution of residuals**|-0.26433|
#
#
# <table><tr><td><img src="../images/dist_190209_133947.png"></td><td><img src="../images/prob_190209_133947.png"></td></tr></table>
#
#
# ---

# %% [markdown]
# ### Model ID: 190209_133848 - ALL timebanks
# #### Selected model
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)
#
# #### Features
# ['const', 'phone', 'facebook', 'mission_sentiment', 'notes_word_count', 'hours_per_exchange', 'avg_offers', 'avg_requests', 'offer_request_ratio', 'members_starting', 'categories_total', 'categories_with_offers', 'categories_with_requests']
#
# |Metric|Value|
# |-----|-----|
# |**Training R2**|0.46166|
# |**Testing R2**|0.39109|
# |**Explained variance**|0.43300|
# |**Mean absolute error (MAE)**|0.59212|
# |**Mean squared error (MSE)**|0.97743|
# |**Root mean squared error (RMSE)**|0.98865|
# |**Median absolute error (MedAE)**|0.25696|
# |**Mean distribution of residuals**|-0.25937|
#
#
# <table><tr><td><img src="../images/dist_190209_133848.png"></td><td><img src="../images/prob_190209_133848.png"></td></tr></table>
#
#
# ---

# %% [markdown]
# ### Model ID: 190209_133743 - ALL timebanks
# #### Selected model
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)
#
# #### Features
# ['const', 'phone', 'facebook', 'mission_sentiment', 'notes_word_count', 'hours_per_exchange', 'avg_offers', 'avg_requests', 'offer_request_ratio', 'members_starting', 'categories_total', 'categories_with_offers', 'categories_with_requests', 'talent_per_cat_per_member']
#
# |Metric|Value|
# |-----|-----|
# |**Training R2**|0.46776|
# |**Testing R2**|0.36058|
# |**Explained variance**|0.40378|
# |**Mean absolute error (MAE)**|0.60154|
# |**Mean squared error (MSE)**|1.02641|
# |**Root mean squared error (RMSE)**|1.01312|
# |**Median absolute error (MedAE)**|0.25850|
# |**Mean distribution of residuals**|-0.26333|
#
#
# <table><tr><td><img src="../images/dist_190209_133743.png"></td><td><img src="../images/prob_190209_133743.png"></td></tr></table>
#
#
# ---

# %% [markdown]
# ### Model ID: 190209_133628 - ALL timebanks
# #### Selected model
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)
#
# #### Features
# ['const', 'phone', 'facebook', 'mission_sentiment', 'notes_word_count', 'hours_per_exchange', 'avg_offers', 'avg_requests', 'offer_request_ratio', 'members_starting', 'facebook_likes', 'categories_total', 'categories_with_offers', 'categories_with_requests', 'talent_per_cat_per_member']
#
# |Metric|Value|
# |-----|-----|
# |**Training R2**|0.53434|
# |**Testing R2**|0.20329|
# |**Explained variance**|0.26781|
# |**Mean absolute error (MAE)**|0.72371|
# |**Mean squared error (MSE)**|1.27890|
# |**Root mean squared error (RMSE)**|1.13088|
# |**Median absolute error (MedAE)**|0.29865|
# |**Mean distribution of residuals**|-0.32183|
#
#
# <table><tr><td><img src="../images/dist_190209_133628.png"></td><td><img src="../images/prob_190209_133628.png"></td></tr></table>
#
#
# ---

# %% [markdown]
# ### Model ID: 190209_133511 - ALL timebanks
# #### Selected model
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)
#
# #### Features
# ['const', 'phone', 'facebook', 'mission_sentiment', 'notes_word_count', 'hours_per_exchange', 'avg_offers', 'avg_requests', 'offer_request_ratio', 'members_starting', 'facebook_likes', 'facebook_followers', 'categories_total', 'categories_with_offers', 'categories_with_requests', 'talent_per_cat_per_member']
#
# |Metric|Value|
# |-----|-----|
# |**Training R2**|0.54911|
# |**Testing R2**|0.19508|
# |**Explained variance**|0.25148|
# |**Mean absolute error (MAE)**|0.72152|
# |**Mean squared error (MSE)**|1.29207|
# |**Root mean squared error (RMSE)**|1.13669|
# |**Median absolute error (MedAE)**|0.32379|
# |**Mean distribution of residuals**|-0.30088|
#
#
# <table><tr><td><img src="../images/dist_190209_133511.png"></td><td><img src="../images/prob_190209_133511.png"></td></tr></table>
#
#
# ---

# %% [markdown]
# ### Model ID: 190209_133412 - ALL timebanks
# #### Selected model
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)
#
# #### Features
# ['const', 'phone', 'facebook', 'notes_word_count', 'hours_per_exchange', 'avg_offers', 'avg_requests', 'offer_request_ratio', 'members_starting', 'facebook_likes', 'facebook_followers', 'categories_total', 'categories_parent', 'categories_with_offers', 'categories_with_requests', 'talent_per_cat_per_member']
#
# |Metric|Value|
# |-----|-----|
# |**Training R2**|0.55129|
# |**Testing R2**|0.17144|
# |**Explained variance**|0.22843|
# |**Mean absolute error (MAE)**|0.72924|
# |**Mean squared error (MSE)**|1.33003|
# |**Root mean squared error (RMSE)**|1.15327|
# |**Median absolute error (MedAE)**|0.33170|
# |**Mean distribution of residuals**|-0.30248|
#
#
# <table><tr><td><img src="../images/dist_190209_133412.png"></td><td><img src="../images/prob_190209_133412.png"></td></tr></table>
#
#
# ---

# %% [markdown]
# ### Model ID: 190209_133300 - ALL timebanks
# #### Selected model
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)
#
# #### Features
# ['const', 'phone', 'facebook', 'mission_sentiment', 'notes_word_count', 'hours_per_exchange', 'avg_offers', 'avg_requests', 'members_starting', 'facebook_likes', 'facebook_followers', 'categories_total', 'categories_parent', 'categories_with_offers', 'categories_with_requests', 'talent_per_cat_per_member']
#
# |Metric|Value|
# |-----|-----|
# |**Training R2**|0.54557|
# |**Testing R2**|0.17878|
# |**Explained variance**|0.23178|
# |**Mean absolute error (MAE)**|0.72633|
# |**Mean squared error (MSE)**|1.31824|
# |**Root mean squared error (RMSE)**|1.14815|
# |**Median absolute error (MedAE)**|0.34215|
# |**Mean distribution of residuals**|-0.29168|
#
#
# <table><tr><td><img src="../images/dist_190209_133300.png"></td><td><img src="../images/prob_190209_133300.png"></td></tr></table>
#
#
# ---

# %% [markdown]
# ### Model ID: 190209_133129 - ALL timebanks
# #### Selected model
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)
#
# #### Features
# ['const', 'phone', 'facebook', 'mission_sentiment', 'notes_word_count', 'hours_per_exchange', 'avg_offers', 'avg_requests', 'offer_request_ratio', 'members_starting', 'facebook_likes', 'facebook_followers', 'categories_total', 'categories_parent', 'categories_with_offers', 'categories_with_requests', 'talent_per_cat_per_member']
#
# |Metric|Value|
# |-----|-----|
# |**Training R2**|0.55172|
# |**Testing R2**|0.19005|
# |**Explained variance**|0.24596|
# |**Mean absolute error (MAE)**|0.71189|
# |**Mean squared error (MSE)**|1.30015|
# |**Root mean squared error (RMSE)**|1.14024|
# |**Median absolute error (MedAE)**|0.31028|
# |**Mean distribution of residuals**|-0.29958|
#
#
# <table><tr><td><img src="../images/dist_190209_133129.png"></td><td><img src="../images/prob_190209_133129.png"></td></tr></table>
#
#
# ---

# %% [markdown]
# ### Model ID: 190209_130009 - ALL timebanks
# #### Selected model
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)
#
# #### Features
# ['const', 'phone', 'facebook', 'mission_word_count', 'mission_sentiment', 'notes_word_count', 'hours_per_exchange', 'avg_offers', 'avg_requests', 'offer_request_ratio', 'members_starting', 'facebook_likes', 'facebook_followers', 'categories_total', 'categories_parent', 'categories_with_offers', 'categories_with_requests', 'talent_per_cat_per_member']
#
# |Metric|Value|
# |-----|-----|
# |**Training R2**|0.55471|
# |**Testing R2**|0.16846|
# |**Explained variance**|0.21820|
# |**Mean absolute error (MAE)**|0.72005|
# |**Mean squared error (MSE)**|1.33481|
# |**Root mean squared error (RMSE)**|1.15534|
# |**Median absolute error (MedAE)**|0.32142|
# |**Mean distribution of residuals**|-0.28258|
#
#
# <table><tr><td><img src="../images/dist_190209_130009.png"></td><td><img src="../images/prob_190209_130009.png"></td></tr></table>
#
#
# ---

# %% [markdown]
# ### Model ID: 190209_125929 - ALL timebanks
# #### Selected model
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)
#
# #### Features
# ['const', 'phone', 'facebook', 'mission_word_count', 'mission_sentiment', 'notes_word_count', 'hours_per_exchange', 'avg_offers', 'avg_requests', 'offer_request_ratio', 'members_starting', 'facebook_likes', 'facebook_followers', 'twitter_tweets', 'categories_total', 'categories_parent', 'categories_with_offers', 'categories_with_requests', 'talent_per_cat_per_member']
#
# |Metric|Value|
# |-----|-----|
# |**Training R2**|0.57728|
# |**Testing R2**|-0.12538|
# |**Explained variance**|-0.10700|
# |**Mean absolute error (MAE)**|0.84738|
# |**Mean squared error (MSE)**|1.80648|
# |**Root mean squared error (RMSE)**|1.34405|
# |**Median absolute error (MedAE)**|0.37680|
# |**Mean distribution of residuals**|-0.17174|
#
#
# <table><tr><td><img src="../images/dist_190209_125929.png"></td><td><img src="../images/prob_190209_125929.png"></td></tr></table>
#
#
# ---

# %% [markdown]
# ### Model ID: 190209_125826 - ALL timebanks
# #### Selected model
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)
#
# #### Features
# ['const', 'phone', 'facebook', 'mission_word_count', 'mission_sentiment', 'notes_word_count', 'hours_per_exchange', 'avg_offers', 'avg_requests', 'offer_request_ratio', 'members_starting', 'facebook_likes', 'facebook_followers', 'twitter_tweets', 'twitter_followers', 'categories_total', 'categories_parent', 'categories_with_offers', 'categories_with_requests', 'talent_per_cat_per_member']
#
# |Metric|Value|
# |-----|-----|
# |**Training R2**|0.59548|
# |**Testing R2**|-0.16524|
# |**Explained variance**|-0.09203|
# |**Mean absolute error (MAE)**|0.78159|
# |**Mean squared error (MSE)**|1.87046|
# |**Root mean squared error (RMSE)**|1.36765|
# |**Median absolute error (MedAE)**|0.34894|
# |**Mean distribution of residuals**|-0.34279|
#
#
# <table><tr><td><img src="../images/dist_190209_125826.png"></td><td><img src="../images/prob_190209_125826.png"></td></tr></table>
#
#
# ---

# %% [markdown]
# ### Model ID: 190209_125554 - ALL timebanks
# #### Selected model
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)
#
# #### Features
# ['const', 'phone', 'facebook', 'twitter', 'mission_word_count', 'mission_sentiment', 'notes_word_count', 'hours_per_exchange', 'avg_offers', 'avg_requests', 'offer_request_ratio', 'members_starting', 'facebook_likes', 'facebook_followers', 'twitter_tweets', 'twitter_followers', 'categories_total', 'categories_parent', 'categories_with_offers', 'categories_with_requests', 'talent_per_cat_per_member']
#
# |Metric|Value|
# |-----|-----|
# |**Training R2**|0.59700|
# |**Testing R2**|-0.16633|
# |**Explained variance**|-0.08607|
# |**Mean absolute error (MAE)**|0.79542|
# |**Mean squared error (MSE)**|1.87222|
# |**Root mean squared error (RMSE)**|1.36829|
# |**Median absolute error (MedAE)**|0.33682|
# |**Mean distribution of residuals**|-0.35893|
#
#
# <table><tr><td><img src="../images/dist_190209_125554.png"></td><td><img src="../images/prob_190209_125554.png"></td></tr></table>
#
#
# ---

# %% [markdown]
# ### Model ID: 190209_125347 - ALL timebanks
# #### Selected model
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)
#
# #### Features
# ['const', 'phone', 'facebook', 'twitter', 'mission_word_count', 'mission_sentiment', 'notes_word_count', 'hours_per_exchange', 'avg_offers', 'avg_requests', 'offer_request_ratio', 'members_starting', 'facebook_likes', 'facebook_followers', 'twitter_tweets', 'twitter_following', 'twitter_followers', 'categories_total', 'categories_parent', 'categories_with_offers', 'categories_with_requests', 'talent_per_cat_per_member']
#
# |Metric|Value|
# |-----|-----|
# |**Training R2**|0.59752|
# |**Testing R2**|-0.16830|
# |**Explained variance**|-0.08536|
# |**Mean absolute error (MAE)**|0.79595|
# |**Mean squared error (MSE)**|1.87538|
# |**Root mean squared error (RMSE)**|1.36944|
# |**Median absolute error (MedAE)**|0.33547|
# |**Mean distribution of residuals**|-0.36486|
#
#
# <table><tr><td><img src="../images/dist_190209_125347.png"></td><td><img src="../images/prob_190209_125347.png"></td></tr></table>
#
#
# ---

# %% [markdown]
# ### Model ID: 190209_125144 - ALL timebanks
# #### Selected model
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)
#
# #### Features
# ['const', 'sponsor', 'phone', 'facebook', 'twitter', 'mission_word_count', 'mission_sentiment', 'notes_word_count', 'hours_per_exchange', 'avg_offers', 'avg_requests', 'offer_request_ratio', 'members_starting', 'facebook_likes', 'facebook_followers', 'twitter_tweets', 'twitter_following', 'twitter_followers', 'categories_total', 'categories_parent', 'categories_with_offers', 'categories_with_requests', 'talent_per_cat_per_member']
#
# |Metric|Value|
# |-----|-----|
# |**Training R2**|0.59757|
# |**Testing R2**|-0.17827|
# |**Explained variance**|-0.09388|
# |**Mean absolute error (MAE)**|0.79834|
# |**Mean squared error (MSE)**|1.89138|
# |**Root mean squared error (RMSE)**|1.37527|
# |**Median absolute error (MedAE)**|0.35304|
# |**Mean distribution of residuals**|-0.36806|
#
#
# <table><tr><td><img src="../images/dist_190209_125144.png"></td><td><img src="../images/prob_190209_125144.png"></td></tr></table>
#
#
# ---

# %% [markdown]
# ### Model ID: 190209_125009 - ALL timebanks
# #### Selected model
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)
#
# #### Features
# ['const', 'sponsor', 'phone', 'url_2', 'facebook', 'twitter', 'mission_word_count', 'mission_sentiment', 'notes_word_count', 'hours_per_exchange', 'avg_requests', 'offer_request_ratio', 'members_starting', 'facebook_likes', 'facebook_followers', 'twitter_tweets', 'twitter_following', 'twitter_followers', 'categories_total', 'categories_parent', 'categories_with_offers', 'categories_with_requests', 'talent_per_cat_per_member']
#
# |Metric|Value|
# |-----|-----|
# |**Training R2**|0.52974|
# |**Testing R2**|-0.29975|
# |**Explained variance**|-0.24395|
# |**Mean absolute error (MAE)**|0.86264|
# |**Mean squared error (MSE)**|2.08639|
# |**Root mean squared error (RMSE)**|1.44443|
# |**Median absolute error (MedAE)**|0.47417|
# |**Mean distribution of residuals**|-0.29930|
#
#
# <table><tr><td><img src="../images/dist_190209_125009.png"></td><td><img src="../images/prob_190209_125009.png"></td></tr></table>
#
#
# ---

# %% [markdown]
# ### Model ID: 190209_124537 - ALL timebanks
# #### Selected model
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)
#
# #### Features
# ['const', 'sponsor', 'phone', 'url_2', 'facebook', 'twitter', 'mission_word_count', 'mission_sentiment', 'hours_per_exchange', 'avg_offers', 'avg_requests', 'offer_request_ratio', 'members_starting', 'facebook_likes', 'facebook_followers', 'twitter_tweets', 'twitter_following', 'twitter_followers', 'categories_total', 'categories_parent', 'categories_with_offers', 'categories_with_requests', 'talent_per_cat_per_member']
#
# |Metric|Value|
# |-----|-----|
# |**Training R2**|0.58847|
# |**Testing R2**|-0.35051|
# |**Explained variance**|-0.24125|
# |**Mean absolute error (MAE)**|0.83905|
# |**Mean squared error (MSE)**|2.16786|
# |**Root mean squared error (RMSE)**|1.47237|
# |**Median absolute error (MedAE)**|0.37298|
# |**Mean distribution of residuals**|-0.41878|
#
#
# <table><tr><td><img src="../images/dist_190209_124537.png"></td><td><img src="../images/prob_190209_124537.png"></td></tr></table>
#
#
# ---

# %% [markdown]
# ### Model ID: 190209_124343 - ALL timebanks
# #### Selected model
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)
#
# #### Features
# ['const', 'sponsor', 'phone', 'url_2', 'facebook', 'twitter', 'mission_word_count', 'mission_sentiment', 'notes_word_count', 'hours_per_exchange', 'avg_offers', 'avg_requests', 'offer_request_ratio', 'members_starting', 'facebook_likes', 'facebook_followers', 'twitter_tweets', 'twitter_following', 'twitter_followers', 'categories_total', 'categories_parent', 'categories_with_offers', 'categories_with_requests', 'talent_per_cat_per_member']
#
# |Metric|Value|
# |-----|-----|
# |**Training R2**|0.60079|
# |**Testing R2**|-0.22284|
# |**Explained variance**|-0.12285|
# |**Mean absolute error (MAE)**|0.80135|
# |**Mean squared error (MSE)**|1.96293|
# |**Root mean squared error (RMSE)**|1.40105|
# |**Median absolute error (MedAE)**|0.27458|
# |**Mean distribution of residuals**|-0.40064|
#
#
# <table><tr><td><img src="../images/dist_190209_124343.png"></td><td><img src="../images/prob_190209_124343.png"></td></tr></table>
#
#
# ---

# %% [markdown]
# ### Model ID: 190209_124234 - ALL timebanks
# #### Selected model
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)
#
# #### Features
# ['const', 'sponsor', 'phone', 'url_2', 'facebook', 'twitter', 'mission_word_count', 'mission_sentiment', 'notes_word_count', 'notes_sentiment', 'hours_per_exchange', 'avg_offers', 'avg_requests', 'offer_request_ratio', 'members_starting', 'facebook_likes', 'facebook_followers', 'twitter_tweets', 'twitter_following', 'twitter_followers', 'categories_total', 'categories_parent', 'categories_with_offers', 'categories_with_requests', 'talent_per_cat_per_member']
#
# |Metric|Value|
# |-----|-----|
# |**Training R2**|0.60213|
# |**Testing R2**|-0.27827|
# |**Explained variance**|-0.16912|
# |**Mean absolute error (MAE)**|0.81836|
# |**Mean squared error (MSE)**|2.05190|
# |**Root mean squared error (RMSE)**|1.43245|
# |**Median absolute error (MedAE)**|0.26553|
# |**Mean distribution of residuals**|-0.41858|
#
#
# <table><tr><td><img src="../images/dist_190209_124234.png"></td><td><img src="../images/prob_190209_124234.png"></td></tr></table>
#
#
# ---

# %% [markdown]
# ### Model ID: 190209_123916 - ALL timebanks
# #### Selected model
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)
#
# #### Features
# ['const', 'sponsor', 'phone', 'url_2', 'facebook', 'twitter', 'mission_word_count', 'mission_sentiment', 'notes_word_count', 'notes_sentiment', 'hours_per_exchange', 'avg_offers', 'avg_requests', 'offer_request_ratio', 'members_starting', 'members_daily_new', 'facebook_likes', 'facebook_followers', 'twitter_tweets', 'twitter_following', 'twitter_followers', 'categories_total', 'categories_parent', 'categories_with_offers', 'categories_with_requests', 'talent_per_cat_per_member']
#
# |Metric|Value|
# |-----|-----|
# |**Training R2**|0.77063|
# |**Testing R2**|-37.28934|
# |**Explained variance**|-36.93609|
# |**Mean absolute error (MAE)**|1.89260|
# |**Mean squared error (MSE)**|61.46285|
# |**Root mean squared error (RMSE)**|7.83982|
# |**Median absolute error (MedAE)**|0.19165|
# |**Mean distribution of residuals**|0.75303|
#
#
# <table><tr><td><img src="../images/dist_190209_123916.png"></td><td><img src="../images/prob_190209_123916.png"></td></tr></table>
#
#
# ---
